# %%
import os
import re
import shutil
import time
from pathlib import Path

from dotenv import load_dotenv
from github import Github
import pandas as pd
import requests

load_dotenv()

github = Github(os.getenv('GITHUB_TOKEN'))
repo   = github.get_repo("AlejandroDiBattista/tup25-p4")

def leer(origen: str = "./alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()

            if sline.startswith("##"):
                # Tomar último caracter numérico de la cabecera (p. ej. '## Comisión 1')
                comision = "C" + sline.strip("# \n")[-1]

            if sline.startswith("- "):
                sline = sline.replace("@","")
                partes = re.split(r"\s{2,}", sline.strip("- \n@"))
                if len(partes) < 5:
                    partes.append("")
                legajo, nombre, telefono, practicos, github = partes
                valores = [legajo, nombre, telefono, github, comision]
                valores = dict(zip('legajo nombre telefono github comision'.split(), valores))

                for i, p in enumerate(practicos, 1):
                    if p == "0": p = "🔴"
                    if p == "1": p = "🟢"
                    valores[f"TP{i}"] = p

                salida.append(valores)
    print(f"| {len(salida)} alumnos leídos.")
    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md", orden_practicos=False):
    """
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """
    def orden_estado(alumno):
        if all(alumno[p] == "🔴" for p in practicos):
            return 100
        for i, p in enumerate(practicos, 1):
            if alumno[p] == "🔴":
                return i
        return 99
    
    def normalizar_presentados(practicos):
        salida = []
        for p in practicos:
            if p == "0": p = "🔴"
            if p == "⚪": p = "🔴"
            if p == "1": p = "🟢"
            salida.append(p)
        return "".join(salida)
    
    practicos = [f"TP{i}" for i in range(1, 20)]
    practicos = [p for p in practicos if p in alumnos[0]]

    print(f"> Escribiendo {destino}...")

    if orden_practicos:
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], orden_estado(alumno), alumno["nombre"]])
    else:
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], alumno["nombre"]])
        
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision[-1]}\n\n")
            archivo.write("```text\n")
            for alumno in alumnos:
                presentado = map(str, [alumno[p] for p in practicos])
                presentado = normalizar_presentados(presentado)
                github = f"@{alumno['github']}" if len(alumno['github']) else ""
                if alumno['comision'] == comision:
                    archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:40}  {alumno['telefono']}  {presentado}  {github:20}\n")
            archivo.write("```\n")
    print(f"| {len(alumnos)} alumnos guardados")
    return alumnos


def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            if alumno['github'].strip() == "": continue
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                nombres = nombre_completo
                apellidos = ""
            
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {alumno['legajo']} - Comision: P4-{alumno['comision']} - Github: {alumno['github']}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")

    print(f"| Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    if orden!="practicos":
        alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen, orden_practicos= orden=="practicos")


def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"../tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro.
    
    Si existe una carpeta con el mismo legajo pero nombre diferente, la renombra.
    Si no existe carpeta, la crea nueva.
    """
    raiz = Path('../tp')  # Usar la ruta correcta hacia tp/
    raiz.mkdir(parents=True, exist_ok=True)  # Asegurar que el directorio tp existe
    
    print(f"> Procesando {len(alumnos)} alumnos en {raiz}...")
    for a in alumnos:
        # Calcular nombre de carpeta destino (sin el prefijo ../tp/)
        destino = raiz / f"{a['legajo']} - {a['nombre']}"
        
        # Buscar carpetas existentes con el mismo legajo
        carpetas_existentes = list(raiz.glob(f"{a['legajo']} -*"))

        if carpetas_existentes:
            # Si existe al menos una carpeta con este legajo
            carpeta_actual = carpetas_existentes[0]  # Tomar la primera
            
            if carpeta_actual != destino:
                # Si el nombre es diferente, renombrar
                print(f"  Renombrando: {carpeta_actual} \n             > {destino}")
                try:
                    carpeta_actual.rename(destino)
                except Exception as e:
                    print(f"Error al renombrar {carpeta_actual}: {e}")
                    continue
        else:
            # Si no existe carpeta con este legajo, crearla
            print(f"Creando nueva carpeta: {destino}")
            destino.mkdir(parents=True, exist_ok=True)

        # Asegurar que la carpeta existe y escribir/actualizar info.txt
        info_file = destino / "info.txt"
        if not info_file.exists():
            info_content = (
                f"Legajo: {a['legajo']}\n"
                f"Nombre: {a['nombre']}\n"
                f"Teléfono: {a['telefono']}\n"
                f"Comisión: {a['comision']}\n"
            )
            info_file.write_text(info_content, encoding='utf-8')
            print(f"Creado info.txt en: {destino}")


def normalizar_carpetas():
    """ Normaliza el archivo y crea las carpetas correspondientes. """
    alumnos = leer()
    print("> Normalizando nombres de carpetas...")
    crear_carpetas(alumnos)
    print("| Proceso normalización de carpetas finalizado.")

alumnos = leer()
normalizar(orden="practicos")
normalizar_carpetas()

# crear_carpetas(leer())
# Out:
# > Leyendo ./alumnos.md...
# | 82 alumnos leídos.
# > Leyendo alumnos.md...
# | 82 alumnos leídos.
# > Escribiendo alumnos.md...
# | 82 alumnos guardados
# > Leyendo ./alumnos.md...
# | 82 alumnos leídos.
# > Normalizando nombres de carpetas...
# > Procesando 82 alumnos en ../tp...
# Creando nueva carpeta: ../tp/54911 - Jatib, Rodrigo Gabriel
# Creado info.txt en: ../tp/54911 - Jatib, Rodrigo Gabriel
# Creando nueva carpeta: ../tp/61033 - Quiroga, José María
# Creado info.txt en: ../tp/61033 - Quiroga, José María
# Creando nueva carpeta: ../tp/61035 - Ledesma, Paulo Marcelo
# Creado info.txt en: ../tp/61035 - Ledesma, Paulo Marcelo
# Creando nueva carpeta: ../tp/61046 - Ponce, Luz Micaela
# Creado info.txt en: ../tp/61046 - Ponce, Luz Micaela
# Creando nueva carpeta: ../tp/61073 - González Chavez, Rodrigo
# Creado info.txt en: ../tp/61073 - González Chavez, Rodrigo
# Creando nueva carpeta: ../tp/61084 - Ramírez, Leonardo
# Creado info.txt en: ../tp/61084 - Ramírez, Leonardo
# Creando nueva carpeta: ../tp/61115 - Ledesma, Santiago Esteban
# Creado info.txt en: ../tp/61115 - Ledesma, Santiago Esteban
# Creando nueva carpeta: ../tp/61120 - Guerrero, Ana Sofía
# Creado info.txt en: ../tp/61120 - Guerrero, Ana Sofía
# Creando nueva carpeta: ../tp/61131 - Agostino Colombres, Juan Manuel
# Creado info.txt en: ../tp/61131 - Agostino Colombres, Juan Manuel
# Creando nueva carpeta: ../tp/61167 - Giacobbe, Franco
# Creado info.txt en: ../tp/61167 - Giacobbe, Franco
# Creando nueva carpeta: ../tp/61198 - Ferreyra Appas, Santiago Nicolás
# Creado info.txt en: ../tp/61198 - Ferreyra Appas, Santiago Nicolás
# Creando nueva carpeta: ../tp/61236 - Drachenberg, Franco Eduardo
# Creado info.txt en: ../tp/61236 - Drachenberg, Franco Eduardo
# Creando nueva carpeta: ../tp/61240 - Timo, Héctor Gabriel
# Creado info.txt en: ../tp/61240 - Timo, Héctor Gabriel
# Creando nueva carpeta: ../tp/61315 - Robles, Thiago
# Creado info.txt en: ../tp/61315 - Robles, Thiago
# Creando nueva carpeta: ../tp/61335 - León, Lucas Ismael
# Creado info.txt en: ../tp/61335 - León, Lucas Ismael
# Creando nueva carpeta: ../tp/61337 - Díaz, Christian Gabriel
# Creado info.txt en: ../tp/61337 - Díaz, Christian Gabriel
# Creando nueva carpeta: ../tp/61338 - Morales, Juan Daniel
# Creado info.txt en: ../tp/61338 - Morales, Juan Daniel
# Creando nueva carpeta: ../tp/61463 - González, Vladimir
# Creado info.txt en: ../tp/61463 - González, Vladimir
# Creando nueva carpeta: ../tp/61468 - Samaniego, Esteban Maximiliano
# Creado info.txt en: ../tp/61468 - Samaniego, Esteban Maximiliano
# Creando nueva carpeta: ../tp/61472 - Díaz, Julieta Camila
# Creado info.txt en: ../tp/61472 - Díaz, Julieta Camila
# Creando nueva carpeta: ../tp/61551 - Díaz Valdez, Ignacio
# Creado info.txt en: ../tp/61551 - Díaz Valdez, Ignacio
# Creando nueva carpeta: ../tp/61565 - Carrizo, Mauro
# Creado info.txt en: ../tp/61565 - Carrizo, Mauro
# Creando nueva carpeta: ../tp/61725 - Villagra, Jorge Sebastián
# Creado info.txt en: ../tp/61725 - Villagra, Jorge Sebastián
# Creando nueva carpeta: ../tp/61805 - Jerez, Tomás
# Creado info.txt en: ../tp/61805 - Jerez, Tomás
# Creando nueva carpeta: ../tp/61813 - Figueroa, Manuel
# Creado info.txt en: ../tp/61813 - Figueroa, Manuel
# Creando nueva carpeta: ../tp/61911 - Llanos, Luciano
# Creado info.txt en: ../tp/61911 - Llanos, Luciano
# Creando nueva carpeta: ../tp/61993 - Medina, Juan Ignacio
# Creado info.txt en: ../tp/61993 - Medina, Juan Ignacio
# Creando nueva carpeta: ../tp/62171 - Ballespin, Cristián
# Creado info.txt en: ../tp/62171 - Ballespin, Cristián
# Creando nueva carpeta: ../tp/62175 - Quiroga, Marcela Noemí
# Creado info.txt en: ../tp/62175 - Quiroga, Marcela Noemí
# Creando nueva carpeta: ../tp/62263 - Orellana, José Augusto
# Creado info.txt en: ../tp/62263 - Orellana, José Augusto
# Creando nueva carpeta: ../tp/62318 - Quiroga Castro, Lisandro
# Creado info.txt en: ../tp/62318 - Quiroga Castro, Lisandro
# Creando nueva carpeta: ../tp/99001 - Branda, César
# Creado info.txt en: ../tp/99001 - Branda, César
# Creando nueva carpeta: ../tp/61028 - Ponce, Rodrigo Exequíel
# Creado info.txt en: ../tp/61028 - Ponce, Rodrigo Exequíel
# Creando nueva carpeta: ../tp/61032 - Moya, Mariano
# Creado info.txt en: ../tp/61032 - Moya, Mariano
# Creando nueva carpeta: ../tp/61037 - Paz, Rodrigo Federico
# Creado info.txt en: ../tp/61037 - Paz, Rodrigo Federico
# Creando nueva carpeta: ../tp/61059 - Palavecino, Fabricio Gastón
# Creado info.txt en: ../tp/61059 - Palavecino, Fabricio Gastón
# Creando nueva carpeta: ../tp/61096 - Suárez Vece, Leandro Andrés
# Creado info.txt en: ../tp/61096 - Suárez Vece, Leandro Andrés
# Creando nueva carpeta: ../tp/61113 - Oríz Caballero, Juan José
# Creado info.txt en: ../tp/61113 - Oríz Caballero, Juan José
# Creando nueva carpeta: ../tp/61129 - Tello, Abril María Agostina
# Creado info.txt en: ../tp/61129 - Tello, Abril María Agostina
# Creando nueva carpeta: ../tp/61136 - Sosa, Oscar Ignacio
# Creado info.txt en: ../tp/61136 - Sosa, Oscar Ignacio
# Creando nueva carpeta: ../tp/61139 - Gallo, María Matilde
# Creado info.txt en: ../tp/61139 - Gallo, María Matilde
# Creando nueva carpeta: ../tp/61141 - Di Clemente, María Antonela
# Creado info.txt en: ../tp/61141 - Di Clemente, María Antonela
# Creando nueva carpeta: ../tp/61150 - Molina Navarro, Juan Martín
# Creado info.txt en: ../tp/61150 - Molina Navarro, Juan Martín
# Creando nueva carpeta: ../tp/61197 - Romano, Alfredo Nicolás
# Creado info.txt en: ../tp/61197 - Romano, Alfredo Nicolás
# Creando nueva carpeta: ../tp/61200 - Gauna Serrano, Martín Javier
# Creado info.txt en: ../tp/61200 - Gauna Serrano, Martín Javier
# Creando nueva carpeta: ../tp/61203 - Acevedo Costello, Juan Ignacio
# Creado info.txt en: ../tp/61203 - Acevedo Costello, Juan Ignacio
# Creando nueva carpeta: ../tp/61214 - Collazos Cortez, Máximo Alberto
# Creado info.txt en: ../tp/61214 - Collazos Cortez, Máximo Alberto
# Creando nueva carpeta: ../tp/61221 - Duclós, Marcelo Ezequiel
# Creado info.txt en: ../tp/61221 - Duclós, Marcelo Ezequiel
# Creando nueva carpeta: ../tp/61248 - Palma Collado, Nahuel
# Creado info.txt en: ../tp/61248 - Palma Collado, Nahuel
# Creando nueva carpeta: ../tp/61271 - Donelli, Gerardo Exequíel
# Creado info.txt en: ../tp/61271 - Donelli, Gerardo Exequíel
# Creando nueva carpeta: ../tp/61312 - Paz Berrondo, Lucas David
# Creado info.txt en: ../tp/61312 - Paz Berrondo, Lucas David
# Creando nueva carpeta: ../tp/61319 - Carabajal, José Gabriel
# Creado info.txt en: ../tp/61319 - Carabajal, José Gabriel
# Creando nueva carpeta: ../tp/61352 - García Moya, José Ignacio
# Creado info.txt en: ../tp/61352 - García Moya, José Ignacio
# Creando nueva carpeta: ../tp/61445 - Martínez Campero, Santiago
# Creado info.txt en: ../tp/61445 - Martínez Campero, Santiago
# Creando nueva carpeta: ../tp/61450 - Jiménez Paz, Patricio Agustín
# Creado info.txt en: ../tp/61450 - Jiménez Paz, Patricio Agustín
# Creando nueva carpeta: ../tp/61473 - Lagoria García, Tomás Gustavo
# Creado info.txt en: ../tp/61473 - Lagoria García, Tomás Gustavo
# Creando nueva carpeta: ../tp/61478 - Soto, Antonella
# Creado info.txt en: ../tp/61478 - Soto, Antonella
# Creando nueva carpeta: ../tp/61562 - Helguera, Agustina Elizabeth
# Creado info.txt en: ../tp/61562 - Helguera, Agustina Elizabeth
# Creando nueva carpeta: ../tp/61572 - Parrado Navarrete, Alex Daniel
# Creado info.txt en: ../tp/61572 - Parrado Navarrete, Alex Daniel
# Creando nueva carpeta: ../tp/61579 - Gonzalo, Martín
# Creado info.txt en: ../tp/61579 - Gonzalo, Martín
# Creando nueva carpeta: ../tp/61581 - Naim, Federico Paz
# Creado info.txt en: ../tp/61581 - Naim, Federico Paz
# Creando nueva carpeta: ../tp/61595 - González Patti, Valentín
# Creado info.txt en: ../tp/61595 - González Patti, Valentín
# Creando nueva carpeta: ../tp/61624 - Godoy, Alan
# Creado info.txt en: ../tp/61624 - Godoy, Alan
# Creando nueva carpeta: ../tp/61626 - Díaz Londero, Sergio Gonzalo
# Creado info.txt en: ../tp/61626 - Díaz Londero, Sergio Gonzalo
# Creando nueva carpeta: ../tp/61627 - Juárez Fernández, Lourdes Abril
# Creado info.txt en: ../tp/61627 - Juárez Fernández, Lourdes Abril
# Creando nueva carpeta: ../tp/61667 - Acosta, Maira
# Creado info.txt en: ../tp/61667 - Acosta, Maira
# Creando nueva carpeta: ../tp/61676 - Massey, Maximiliano
# Creado info.txt en: ../tp/61676 - Massey, Maximiliano
# Creando nueva carpeta: ../tp/61679 - Lobo Barrera, María de los Ángeles
# Creado info.txt en: ../tp/61679 - Lobo Barrera, María de los Ángeles
# Creando nueva carpeta: ../tp/61719 - Amoedo, Pablo Isaías
# Creado info.txt en: ../tp/61719 - Amoedo, Pablo Isaías
# Creando nueva carpeta: ../tp/61720 - Fernández, Luciano
# Creado info.txt en: ../tp/61720 - Fernández, Luciano
# Creando nueva carpeta: ../tp/61730 - Díaz, Antonio
# Creado info.txt en: ../tp/61730 - Díaz, Antonio
# Creando nueva carpeta: ../tp/61793 - Trujillo, Facundo Nahuel
# Creado info.txt en: ../tp/61793 - Trujillo, Facundo Nahuel
# Creando nueva carpeta: ../tp/61794 - Lobo Campero, Hernán Ignacio
# Creado info.txt en: ../tp/61794 - Lobo Campero, Hernán Ignacio
# Creando nueva carpeta: ../tp/61818 - López Tisera, Gastón
# Creado info.txt en: ../tp/61818 - López Tisera, Gastón
# Creando nueva carpeta: ../tp/61862 - Zerda, Thomas
# Creado info.txt en: ../tp/61862 - Zerda, Thomas
# Creando nueva carpeta: ../tp/61956 - Leglisé, Laureano
# Creado info.txt en: ../tp/61956 - Leglisé, Laureano
# Creando nueva carpeta: ../tp/62053 - Herrera Palomino, Iván Agustín
# Creado info.txt en: ../tp/62053 - Herrera Palomino, Iván Agustín
# Creando nueva carpeta: ../tp/62055 - Ahumada, Aiquen Osvaldo
# Creado info.txt en: ../tp/62055 - Ahumada, Aiquen Osvaldo
# Creando nueva carpeta: ../tp/62093 - Frías Silva, Juan Segundo
# Creado info.txt en: ../tp/62093 - Frías Silva, Juan Segundo
# Creando nueva carpeta: ../tp/62172 - Salcedo, Mariana Aylén
# Creado info.txt en: ../tp/62172 - Salcedo, Mariana Aylén
# Creando nueva carpeta: ../tp/62555 - Verón, Matías Gabriel
# Creado info.txt en: ../tp/62555 - Verón, Matías Gabriel
# | Proceso normalización de carpetas finalizado.

# %%
def copiar_tp(tp=1, alumnos=None, incluir_ocultos=True, follow_symlinks=False):
    """
    Copia recursivamente todos los archivos y subcarpetas de enunciados/tp{tp}
    a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).

    - incluir_ocultos: si es False, ignora entradas que comienzan con '.' (p. ej. .DS_Store, .git)
    - follow_symlinks: si es True, copia el contenido al que apunta el symlink; si es False, copia el link como archivo
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"../enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    total_archivos = 0
    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        # Recorremos el árbol de 'origen_base' y replicamos estructura + archivos
        for root, dirs, files in os.walk(origen_base):
            root_path = Path(root)

            # Opcional: filtrar carpetas/archivos ocultos
            if not incluir_ocultos:
                dirs[:] = [d for d in dirs if not d.startswith('.')]

            rel = root_path.relative_to(origen_base)
            dest_dir = destino_base / rel
            dest_dir.mkdir(parents=True, exist_ok=True)

            for name in files:
                if not incluir_ocultos and name.startswith('.'):  # p. ej. .DS_Store
                    continue
                src = root_path / name
                dst = dest_dir / name
                try:
                    shutil.copy2(src, dst, follow_symlinks=follow_symlinks)
                    total_archivos += 1
                except Exception as e:
                    print(f"Error copiando {src} -> {dst}: {e}")

    print(f"| Copia finalizada. {len(alumnos)} alumnos, {total_archivos} archivos copiados en total.")


alumnos = leer()
# crear_carpetas(alumnos)
# copiar_tp(3, alumnos)

# %%
# Ejemplo de uso de la función convertir_vcard
alumnos = leer('alumnos.md')
print(f"Se encontraron {len(alumnos)} alumnos")

# Generar archivo VCard con todos los alumnos
contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

print("Archivos VCard generados exitosamente!")
print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")

# %%
# Gestion de repositorio y Pull Requests

def normalizar_titulo(titulo, tp, alumnos):
    if match:= re.search(r'(\d{5})', titulo):
        legajo = match.group(1)
        nombre_alumno = next((a['nombre'] for a in alumnos if a['legajo'] == legajo), "Desconocido")
        return f"TP{tp} - {legajo} - {nombre_alumno}"
    else:
        return titulo

def cargar_github_user(alumnos):
    print(f"> Cargando usuarios de GitHub en {len(alumnos)} alumnos...")

    practicos = set()
    prs = repo.get_pulls(state='closed', sort='created', base='main')
    for pr in prs:
        tp, legajo, *_ = pr.title.split(" - ")
        practicos.add(tp)
        if alumno := next((x for x in alumnos if x['legajo'].strip() == legajo), None):
            alumno["github"] = pr.user.login
            alumno[tp] = 1

    for a in alumnos:
        for c in sorted(practicos):
            if c not in a: 
                a[c] = 0

    print(f"|")
    return alumnos


def normalizar_titulo_pr(tp=3, estado='open', alumnos=None, min=0, max=9999):
    print(f"> Pull Requests pendientes:")

    open_pulls = repo.get_pulls(state=estado, sort='created', base='main')
    for pr in open_pulls:
        if not (min <= pr.number <= max): continue

        pr = repo.get_pull(pr.number)  # Refrescar datos del PR
        nuevo = normalizar_titulo(pr.title, tp, alumnos)
        if pr.title != nuevo:
            print(f"+ #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}{"*" if pr.title != nuevo else ""}")
            print(f"    >>: {pr.title}")
            pr.edit(title=nuevo)
        else:
            print(f"- #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}")

    cols = sorted({c for a in alumnos for c in a.keys() if c.startswith("TP")})

    print(f"| fin {cols}")


def aceptar_prs_sin_conflictos():
    open_pulls = repo.get_pulls(state='open', sort='created', base='main')
    print("> Intentando merge de PRs sin conflictos:")
    for pr in open_pulls:
        pr = repo.get_pull(pr.number)       # Refrescar datos
        if pr.mergeable is None:
            time.sleep(5)
            pr = repo.get_pull(pr.number)   # Refrescar
        if pr.mergeable:
            try:
                pr.merge()
                print(f"- ✅ PR #{pr.number} mergeado: {pr.title}")
            except Exception as e:
                print(f"- ❌ Error al mergear PR #{pr.number}: {e}")
        elif pr.mergeable is False:
            print(f"- 👁️ PR #{pr.number} tiene conflictos: {pr.title}")
        else:
            print(f"- ⏳ Tiempo agotado para PR #{pr.number}: {pr.title}")
    print("| fin")

# Funciones
# 1. normalizar_pr -> renombra los PRs abiertos con formato estandar
# 2. merge_prs_sin_conflictos -> intenta mergear los PRs sin conflictos

alumnos = leer()
normalizar_titulo_pr(tp=3, estado='open', alumnos=alumnos, min=65)
cargar_github_user(alumnos)
escribir(alumnos, "alumnos.md", orden_practicos=True)
# aceptar_prs_sin_conflictos()


# Cargar lista de alumnos en un DataFrame y mostrarlo como tabla
# df_alumnos = pd.DataFrame(alumnos)

# df_alumnos
# Out:
# > Leyendo ./alumnos.md...
# | 82 alumnos leídos.
# > Pull Requests pendientes:
# | fin ['TP1', 'TP2', 'TP3']
# > Cargando usuarios de GitHub en 82 alumnos...
# |
# > Escribiendo alumnos.md...
# | 82 alumnos guardados
# [{'legajo': '61993',
#   'nombre': 'Medina, Juan Ignacio',
#   'telefono': '(381) 517-1937',
#   'github': 'Soulmain1',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61084',
#   'nombre': 'Ramírez, Leonardo',
#   'telefono': '(381) 348-9132',
#   'github': 'Leoramirez777',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61551',
#   'nombre': 'Díaz Valdez, Ignacio',
#   'telefono': '(381) 695-8566',
#   'github': 'IgnacioDiazV',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61120',
#   'nombre': 'Guerrero, Ana Sofía',
#   'telefono': '(381) 418-1564',
#   'github': 'AnaSofi03',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61805',
#   'nombre': 'Jerez, Tomás',
#   'telefono': '(381) 338-0186',
#   'github': 'ElTommmy',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62318',
#   'nombre': 'Quiroga Castro, Lisandro',
#   'telefono': '(381) 390-9133',
#   'github': 'Lisandro-18',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61472',
#   'nombre': 'Díaz, Julieta Camila',
#   'telefono': '(381) 652-9981',
#   'github': 'juliidiiaz04',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61131',
#   'nombre': 'Agostino Colombres, Juan Manuel',
#   'telefono': '(381) 684-8399',
#   'github': 'JuanmaAgostino',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61565',
#   'nombre': 'Carrizo, Mauro',
#   'telefono': '(381) 610-8745',
#   'github': 'DarkoDarkShadow',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61236',
#   'nombre': 'Drachenberg, Franco Eduardo',
#   'telefono': '(381) 670-8708',
#   'github': 'FDrach',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61198',
#   'nombre': 'Ferreyra Appas, Santiago Nicolás',
#   'telefono': '(381) 648-4455',
#   'github': 'Ercutt',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61167',
#   'nombre': 'Giacobbe, Franco',
#   'telefono': '(381) 588-0371',
#   'github': 'frandg47',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61073',
#   'nombre': 'González Chavez, Rodrigo',
#   'telefono': '(381) 624-3000',
#   'github': 'rodrigogc21',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '54911',
#   'nombre': 'Jatib, Rodrigo Gabriel',
#   'telefono': '(381) 655-3096',
#   'github': 'RodrigoJatib',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61035',
#   'nombre': 'Ledesma, Paulo Marcelo',
#   'telefono': '(381) 664-8356',
#   'github': 'pauloled',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61115',
#   'nombre': 'Ledesma, Santiago Esteban',
#   'telefono': '(381) 346-3696',
#   'github': 'santled',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61335',
#   'nombre': 'León, Lucas Ismael',
#   'telefono': '(381) 609-7898',
#   'github': 'LuquitasLeon',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61911',
#   'nombre': 'Llanos, Luciano',
#   'telefono': '(381) 325-9224',
#   'github': 'LucianoLlanos',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61338',
#   'nombre': 'Morales, Juan Daniel',
#   'telefono': '(381) 665-5296',
#   'github': 'JuanMo17',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62263',
#   'nombre': 'Orellana, José Augusto',
#   'telefono': '(381) 339-2050',
#   'github': 'Jaodem',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61046',
#   'nombre': 'Ponce, Luz Micaela',
#   'telefono': '(381) 664-7165',
#   'github': 'Mica8p',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61033',
#   'nombre': 'Quiroga, José María',
#   'telefono': '(11) 2399-7675',
#   'github': 'jose-qui',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62175',
#   'nombre': 'Quiroga, Marcela Noemí',
#   'telefono': '(381) 593-8430',
#   'github': 'Marce-Quiroga',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61315',
#   'nombre': 'Robles, Thiago',
#   'telefono': '(381) 344-7120',
#   'github': 'T1T0Dev',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61468',
#   'nombre': 'Samaniego, Esteban Maximiliano',
#   'telefono': '(381) 679-6586',
#   'github': 'MaxiSama12',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61240',
#   'nombre': 'Timo, Héctor Gabriel',
#   'telefono': '(381) 343-0992',
#   'github': 'GabrielTimo006',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61725',
#   'nombre': 'Villagra, Jorge Sebastián',
#   'telefono': '(381) 594-1635',
#   'github': 'JorgeVillagraa',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62171',
#   'nombre': 'Ballespin, Cristián',
#   'telefono': '(381) 604-5734',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '99001',
#   'nombre': 'Branda, César',
#   'telefono': '(381) 212-6932',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61337',
#   'nombre': 'Díaz, Christian Gabriel',
#   'telefono': '(381) 571-4797',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61813',
#   'nombre': 'Figueroa, Manuel',
#   'telefono': '(381) 544-2423',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61463',
#   'nombre': 'González, Vladimir',
#   'telefono': '(381) 419-4154',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61624',
#   'nombre': 'Godoy, Alan',
#   'telefono': '(381) 574-4877',
#   'github': 'AlanG46',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': 1,
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62172',
#   'nombre': 'Salcedo, Mariana Aylén',
#   'telefono': '(381) 466-9695',
#   'github': 'marianasalcedo22',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61129',
#   'nombre': 'Tello, Abril María Agostina',
#   'telefono': '(381) 447-2483',
#   'github': 'abriltello',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61096',
#   'nombre': 'Suárez Vece, Leandro Andrés',
#   'telefono': '(381) 512-6476',
#   'github': 'leandroVece',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61203',
#   'nombre': 'Acevedo Costello, Juan Ignacio',
#   'telefono': '(381) 388-7804',
#   'github': 'Ignacioacevedoo',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61667',
#   'nombre': 'Acosta, Maira',
#   'telefono': '(381) 562-8162',
#   'github': 'maira-acostaa',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62055',
#   'nombre': 'Ahumada, Aiquen Osvaldo',
#   'telefono': '(381) 419-9202',
#   'github': 'aiquen7',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61719',
#   'nombre': 'Amoedo, Pablo Isaías',
#   'telefono': '(381) 463-6126',
#   'github': 'Kryfter',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61319',
#   'nombre': 'Carabajal, José Gabriel',
#   'telefono': '(381) 319-2680',
#   'github': '7GabrielC',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61141',
#   'nombre': 'Di Clemente, María Antonela',
#   'telefono': '(381) 398-3935',
#   'github': 'antodiclemente',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61271',
#   'nombre': 'Donelli, Gerardo Exequíel',
#   'telefono': '(381) 514-3223',
#   'github': 'GerardoExe',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61221',
#   'nombre': 'Duclós, Marcelo Ezequiel',
#   'telefono': '(381) 551-4353',
#   'github': 'EzeDuclos',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61626',
#   'nombre': 'Díaz Londero, Sergio Gonzalo',
#   'telefono': '(381) 604-6547',
#   'github': 'Gonzalo-diazz',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62093',
#   'nombre': 'Frías Silva, Juan Segundo',
#   'telefono': '(381) 415-8753',
#   'github': 'juansefriass',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61139',
#   'nombre': 'Gallo, María Matilde',
#   'telefono': '(381) 333-4836',
#   'github': 'matildegallom',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61200',
#   'nombre': 'Gauna Serrano, Martín Javier',
#   'telefono': '(381) 389-2631',
#   'github': 'MartinGS8',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61579',
#   'nombre': 'Gonzalo, Martín',
#   'telefono': '(381) 418-6882',
#   'github': 'Lived18',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62053',
#   'nombre': 'Herrera Palomino, Iván Agustín',
#   'telefono': '(381) 697-0643',
#   'github': 'ivanagustinherrera',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61450',
#   'nombre': 'Jiménez Paz, Patricio Agustín',
#   'telefono': '(381) 388-2674',
#   'github': 'patricio-jp',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61627',
#   'nombre': 'Juárez Fernández, Lourdes Abril',
#   'telefono': '(381) 647-9914',
#   'github': 'LourdesFernandez1',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61473',
#   'nombre': 'Lagoria García, Tomás Gustavo',
#   'telefono': '(381) 357-7724',
#   'github': 'tomaslago27',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61794',
#   'nombre': 'Lobo Campero, Hernán Ignacio',
#   'telefono': '(381) 590-6461',
#   'github': 'lobohhernan',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61818',
#   'nombre': 'López Tisera, Gastón',
#   'telefono': '(381) 523-5887',
#   'github': 'gastonlopezt',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61445',
#   'nombre': 'Martínez Campero, Santiago',
#   'telefono': '(381) 646-6685',
#   'github': 'SantiCampero',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61676',
#   'nombre': 'Massey, Maximiliano',
#   'telefono': '(381) 359-9941',
#   'github': 'EPILONgaga',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61150',
#   'nombre': 'Molina Navarro, Juan Martín',
#   'telefono': '(381) 644-3413',
#   'github': 'JuanMolinaNavarro',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61032',
#   'nombre': 'Moya, Mariano',
#   'telefono': '(381) 670-1164',
#   'github': 'mariano-moya',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61113',
#   'nombre': 'Oríz Caballero, Juan José',
#   'telefono': '(381) 631-7223',
#   'github': 'JuanchoCab',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61248',
#   'nombre': 'Palma Collado, Nahuel',
#   'telefono': '(381) 674-7012',
#   'github': 'Nahu333',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61572',
#   'nombre': 'Parrado Navarrete, Alex Daniel',
#   'telefono': '(381) 409-5039',
#   'github': 'AlexDaniel28',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61312',
#   'nombre': 'Paz Berrondo, Lucas David',
#   'telefono': '(381) 341-4321',
#   'github': 'Lucasdxvid',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61037',
#   'nombre': 'Paz, Rodrigo Federico',
#   'telefono': '(381) 637-6461',
#   'github': 'Rodrigopz52',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61028',
#   'nombre': 'Ponce, Rodrigo Exequíel',
#   'telefono': '(381) 569-0318',
#   'github': 'rodrikapo12',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61197',
#   'nombre': 'Romano, Alfredo Nicolás',
#   'telefono': '(381) 648-8513',
#   'github': 'NicoRomano904',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61136',
#   'nombre': 'Sosa, Oscar Ignacio',
#   'telefono': '(381) 528-9145',
#   'github': 'Oscar40997',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61478',
#   'nombre': 'Soto, Antonella',
#   'telefono': '(387) 517-0010',
#   'github': 'anto210',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61793',
#   'nombre': 'Trujillo, Facundo Nahuel',
#   'telefono': '(381) 206-2084',
#   'github': 'FacundoTrujillo',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62555',
#   'nombre': 'Verón, Matías Gabriel',
#   'telefono': '(381) 519-6654',
#   'github': 'MatiasVeron12503',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61214',
#   'nombre': 'Collazos Cortez, Máximo Alberto',
#   'telefono': '(381) 350-5275',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61730',
#   'nombre': 'Díaz, Antonio',
#   'telefono': '(381) 392-6461',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61720',
#   'nombre': 'Fernández, Luciano',
#   'telefono': '(381) 586-7891',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61352',
#   'nombre': 'García Moya, José Ignacio',
#   'telefono': '(381) 638-9006',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61595',
#   'nombre': 'González Patti, Valentín',
#   'telefono': '(381) 655-9195',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61562',
#   'nombre': 'Helguera, Agustina Elizabeth',
#   'telefono': '(381) 694-9619',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61956',
#   'nombre': 'Leglisé, Laureano',
#   'telefono': '(261) 468-9809',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61679',
#   'nombre': 'Lobo Barrera, María de los Ángeles',
#   'telefono': '(381) 677-0639',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61581',
#   'nombre': 'Naim, Federico Paz',
#   'telefono': '(381) 353-0060',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '62263',
#   'nombre': 'Orellana, José Augusto',
#   'telefono': '(386) 534-2925',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61059',
#   'nombre': 'Palavecino, Fabricio Gastón',
#   'telefono': '(381) 666-6103',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0},
#  {'legajo': '61862',
#   'nombre': 'Zerda, Thomas',
#   'telefono': '(381) 333-0962',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'Corrijo entrega TP3': 0}]

# %%
def descargar_avatar_github(username: str, destino: str | Path = "./avatars", nombre_archivo: str | None = None, token: str | None = None, use_direct_url: bool = True) -> Path:
    destino = Path(destino)
    destino.mkdir(parents=True, exist_ok=True)

    base = nombre_archivo if nombre_archivo else username

    def _guardar(img_resp: requests.Response, ruta_base: Path) -> Path:
        # Elegir extensión por Content-Type
        content_type = img_resp.headers.get("Content-Type", "").lower()
        _ext = ".jpg"
        if "png" in content_type:
            _ext = ".png"
        elif any(x in content_type for x in ["jpeg", "jpg"]):
            _ext = ".jpg"
        elif "gif" in content_type:
            _ext = ".gif"
        destino_archivo = ruta_base.with_suffix(_ext)
        with open(destino_archivo, "wb") as f:
            for chunk in img_resp.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print(f"Avatar guardado en: {destino_archivo}")
        return destino_archivo

    # 1) Intentar descargar directamente desde la URL pública del avatar (sin consumir API core)
    if use_direct_url:
        direct_url = f"https://github.com/{username}.png"
        try:
            img_resp = requests.get(direct_url, stream=True, timeout=30)
            if img_resp.status_code == 200:
                return _guardar(img_resp, destino / base)
            else:
                print(f"No se pudo usar URL directa ({img_resp.status_code}), se intentará API.")
        except Exception as e:
            print(f"Fallo URL directa: {e}. Se intentará API.")

    # 2) Consultar API para obtener avatar_url (con token si está disponible)
    token = token or os.getenv("GITHUB_TOKEN")
    headers = {"Accept": "application/vnd.github+json"}
    if token:
        headers["Authorization"] = f"Bearer {token}"

    url = f"https://api.github.com/users/{username}"
    resp = requests.get(url, headers=headers, timeout=20)
    if resp.status_code == 403:
        # Rate limit excedido
        reset = resp.headers.get("X-RateLimit-Reset")
        if reset and reset.isdigit():
            wait = max(0, int(reset) - int(time.time()) + 2)
            raise RuntimeError(f"Rate limit excedido. Reintentar en ~{wait}s o usar un token válido en GITHUB_TOKEN.")
        raise RuntimeError("Rate limit excedido. Configure GITHUB_TOKEN para aumentar el límite (hasta 5000/hora).")
    resp.raise_for_status()
    data = resp.json()
    avatar_url = data.get("avatar_url")
    if not avatar_url:
        raise RuntimeError(f"No se encontró avatar para el usuario: {username}")

    img_resp = requests.get(avatar_url, stream=True, timeout=30)
    img_resp.raise_for_status()
    return _guardar(img_resp, destino / base)


def bajar_avatars():
    descargados = []

    alumnos = leer()
    for alumno in alumnos:
        gh = (alumno.get('github') or "").strip("@ ")
        if not gh: continue
        destino = Path(carpeta(alumno))  # carpeta devuelve ../tp/<legajo> - <nombre>
        destino.mkdir(parents=True, exist_ok=True)
        nombre_base = str(alumno['legajo'])
        try:
            ruta = descargar_avatar_github(gh, destino=destino, nombre_archivo=nombre_base, use_direct_url=True)
            descargados.append(ruta)
            time.sleep(0.2)  # pequeño throttle para ser buen ciudadano
        except Exception as e:
            print(f"No se pudo bajar avatar de {gh} ({alumno['legajo']}): {e}")

    print(f"Avatares descargados: {len(descargados)}")
# Ejemplo individual:
bajar_avatars()
# descargar_avatar_github("alejandrodibattista")
