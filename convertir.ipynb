# %%
import os
import re
import shutil
import time
from pathlib import Path

from dotenv import load_dotenv
from github import Github
import pandas as pd
import requests

load_dotenv()

github = Github(os.getenv('GITHUB_TOKEN'))
repo   = github.get_repo("AlejandroDiBattista/tup25-p4")

def leer(origen: str = "./alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()

            if sline.startswith("##"):
                # Tomar último caracter numérico de la cabecera (p. ej. '## Comisión 1')
                comision = "C" + sline.strip("# \n")[-1]

            if sline.startswith("- "):
                sline = sline.replace("@","")
                partes = re.split(r"\s{2,}", sline.strip("- \n@"))
                if len(partes) < 5:
                    partes.append("")
                legajo, nombre, telefono, practicos, github = partes
                valores = dict(zip(['legajo', 'nombre', 'telefono', 'github', 'comision'], [legajo, nombre, telefono, github, comision]))

                for i, p in enumerate(practicos, 1):
                    match p:
                        case "0": p = "🔴"
                        case "1": p = "🟢"
                    valores[f"TP{i}"] = p

                salida.append(valores)
    print(f"| {len(salida)} alumnos leídos.")
    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md", orden_practicos=False):
    """
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """
    def orden_estado(alumno):
        if all(alumno[p] == "🔴" for p in practicos):
            return 100
        
        for i, p in enumerate(practicos, 1):
            if alumno[p] == "🔴":
                return i
        
        return 99
    
    def normalizar_presentados(practicos):
        salida = []
        for p in practicos:
            match p:
                case "0" | "⚪": p = "🔴"
                case "1": p = "🟢"
            salida.append(p)
        return "".join(salida)
    
    practicos = [f"TP{i}" for i in range(1, 20)]
    practicos = [p for p in practicos if p in alumnos[0]]

    print(f"> Escribiendo {destino}...")

    if orden_practicos:
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], orden_estado(alumno), alumno["nombre"]])
    else:
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], alumno["nombre"]])
        
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision[-1]}\n\n")
            archivo.write("```text\n")
            for alumno in alumnos:
                presentado = map(str, [alumno[p] for p in practicos])
                presentado = normalizar_presentados(presentado)
                github = f"@{alumno['github']}" if len(alumno['github']) else ""
                if alumno['comision'] == comision:
                    archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:40}  {alumno['telefono']}  {presentado}  {github:20}\n")
            archivo.write("```\n")
    print(f"| {len(alumnos)} alumnos guardados")
    return alumnos


def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            if alumno['github'].strip() == "": continue
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                nombres = nombre_completo
                apellidos = ""
            
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {alumno['legajo']} - Comision: P4-{alumno['comision']} - Github: {alumno['github']}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")

    print(f"| Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    if orden != "practicos":
        alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen, orden_practicos= orden=="practicos")

# Ejemplo de uso de la función convertir_vcard
alumnos = leer('alumnos.md')
print(f"Se encontraron {len(alumnos)} alumnos")

# Generar archivo VCard con todos los alumnos
contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

print("Archivos VCard generados exitosamente!")
print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")
# Out:
# > Leyendo alumnos.md...
# | 82 alumnos leídos.
# Se encontraron 82 alumnos
# > Generando archivo VCard: alumnos.vcf...
# | Archivo generado con 82 contactos.
# Archivos VCard generados exitosamente!
# Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.

# %%
def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"./tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro.
    
    Si existe una carpeta con el mismo legajo pero nombre diferente, la renombra.
    Si no existe carpeta, la crea nueva.
    """
    raiz = Path('../tp')  # Usar la ruta correcta hacia tp/
    raiz.mkdir(parents=True, exist_ok=True)  # Asegurar que el directorio tp existe
    
    print(f"> Procesando {len(alumnos)} alumnos en {raiz}...")
    for a in alumnos:
        # Calcular nombre de carpeta destino (sin el prefijo ../tp/)
        destino = raiz / f"{a['legajo']} - {a['nombre']}"
        
        # Buscar carpetas existentes con el mismo legajo
        carpetas_existentes = list(raiz.glob(f"{a['legajo']} -*"))

        if carpetas_existentes:
            # Si existe al menos una carpeta con este legajo
            carpeta_actual = carpetas_existentes[0]  # Tomar la primera
            
            if carpeta_actual != destino:
                # Si el nombre es diferente, renombrar
                print(f"  Renombrando: {carpeta_actual} \n             > {destino}")
                try:
                    carpeta_actual.rename(destino)
                except Exception as e:
                    print(f"Error al renombrar {carpeta_actual}: {e}")
                    continue
        else:
            # Si no existe carpeta con este legajo, crearla
            print(f"Creando nueva carpeta: {destino}")
            destino.mkdir(parents=True, exist_ok=True)

        # Asegurar que la carpeta existe y escribir/actualizar info.txt
        info_file = destino / "info.txt"
        if not info_file.exists():
            info_content = (
                f"Legajo: {a['legajo']}\n"
                f"Nombre: {a['nombre']}\n"
                f"Teléfono: {a['telefono']}\n"
                f"Comisión: {a['comision']}\n"
            )
            info_file.write_text(info_content, encoding='utf-8')
            print(f"Creado info.txt en: {destino}")


def normalizar_carpetas():
    """ Normaliza el archivo y crea las carpetas correspondientes. """
    alumnos = leer()
    print("> Normalizando nombres de carpetas...")
    crear_carpetas(alumnos)
    print("| Proceso normalización de carpetas finalizado.")

# alumnos = leer()
# normalizar(orden="practicos")
# normalizar_carpetas()

# crear_carpetas(leer())

# %%
def copiar_tp(tp=1, alumnos=None, incluir_ocultos=True, follow_symlinks=False):
    """
    Copia recursivamente todos los archivos y subcarpetas de enunciados/tp{tp}
    a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).

    - incluir_ocultos: si es False, ignora entradas que comienzan con '.' (p. ej. .DS_Store, .git)
    - follow_symlinks: si es True, copia el contenido al que apunta el symlink; si es False, copia el link como archivo
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"./enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    total_archivos = 0
    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        # Recorremos el árbol de 'origen_base' y replicamos estructura + archivos
        for root, dirs, files in os.walk(origen_base):
            root_path = Path(root)

            # Opcional: filtrar carpetas/archivos ocultos
            if not incluir_ocultos:
                dirs[:] = [d for d in dirs if not d.startswith('.')]

            rel = root_path.relative_to(origen_base)
            dest_dir = destino_base / rel
            dest_dir.mkdir(parents=True, exist_ok=True)

            for name in files:
                if not incluir_ocultos and name.startswith('.'):  # p. ej. .DS_Store
                    continue
                src = root_path / name
                dst = dest_dir / name
                try:
                    shutil.copy2(src, dst, follow_symlinks=follow_symlinks)
                    total_archivos += 1
                except Exception as e:
                    print(f"Error copiando {src} -> {dst}: {e}")

    print(f"| Copia finalizada. {len(alumnos)} alumnos, {total_archivos} archivos copiados en total.")


alumnos = leer()
crear_carpetas(alumnos)
copiar_tp(6, alumnos)
# Out:
# > Leyendo ./alumnos.md...
# | 82 alumnos leídos.
# > Procesando 82 alumnos en ../tp...
#   Renombrando: ../tp/61463 - González, Nicolas (oyente)
#              > ../tp/61463 - González, Vladimir
#   Renombrando: ../tp/61463 - González, Vladimir
#              > ../tp/61463 - González, Nicolas (oyente)
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/54911 - Jatib, Rodrigo Gabriel/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/54911 - Jatib, Rodrigo Gabriel/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/54911 - Jatib, Rodrigo Gabriel/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/54911 - Jatib, Rodrigo Gabriel/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp
tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python3.13') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62172 - Salcedo, Mariana Aylén/tp6/backend/.venv/bin/python3.13') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3.13') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62263 - Orellana, José Augusto/tp6/backend/.venv/bin/python3.13') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3.13') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3 -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3: PosixPath('enunciados/tp6/backend/.venv/bin/python3') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python: PosixPath('enunciados/tp6/backend/.venv/bin/python') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python') are the same file
# Error copiando enunciados/tp6/backend/.venv/bin/python3.13 -> tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3.13: PosixPath('enunciados/tp6/backend/.venv/bin/python3.13') and PosixPath('tp/62555 - Verón, Matías Gabriel/tp6/backend/.venv/bin/python3.13') are the same file
# | Copia finalizada. 82 alumnos, 163426 archivos copiados en total.
# | Copia finalizada. 82 alumnos, 163426 archivos copiados en total.

# %%
# Gestion de repositorio y Pull Requests

def normalizar_titulo(titulo, tp, alumnos):
    if match:= re.search(r'(\d{5})', titulo):
        legajo = match.group(1)
        nombre_alumno = next((a['nombre'] for a in alumnos if a['legajo'] == legajo), "Desconocido")
        return f"TP{tp} - {legajo} - {nombre_alumno}"
    else:
        return titulo

def cargar_github_user(alumnos):
    print(f"> Cargando usuarios de GitHub en {len(alumnos)} alumnos...")

    practicos = set()
    prs = repo.get_pulls(state='closed', sort='created', base='main')
    for pr in prs:
        # Verificar que el PR fue mergeado, no solo cerrado
        if not pr.merged:
            continue
            
        tp, legajo, *_ = pr.title.split(" - ")
        practicos.add(tp)
        if alumno := next((x for x in alumnos if x['legajo'].strip() == legajo), None):
            alumno["github"] = pr.user.login
            alumno[tp] = 1

    for a in alumnos:
        for c in sorted(practicos):
            if c not in a: 
                a[c] = 0

    print(f"|")
    return alumnos


def averiguar_presentacion_practicos(alumnos):
    print(f"> Averiguando presentación de prácticos en {len(alumnos)} alumnos...")

    practicos = set()
    prs = repo.get_pulls(state='closed', sort='created', base='main')
    for pr in prs:
        # Verificar que el PR fue mergeado, no solo cerrado
        if not pr.merged:
            print(f"x PR #{pr.number}: {pr.title} (cerrado sin merge)")
            continue
            
        print(f"✓ PR #{pr.number}: {pr.title}")
        tp, legajo, *_ = pr.title.split(" - ")
        practicos.add(tp)
        if alumno := next((x for x in alumnos if x['legajo'].strip() == legajo), None):
            alumno[tp] = 1

    for a in alumnos:
        for c in sorted(practicos):
            if c not in a: 
                a[c] = 0

    print(f"|")
    return alumnos


def normalizar_titulo_pr(tp=5, estado='open', alumnos=None, min=0, max=9999):
    print(f"> Pull Requests pendientes:")

    open_pulls = repo.get_pulls(state=estado, sort='created', base='main')
    for pr in open_pulls:
        if not (min <= pr.number <= max): continue

        pr = repo.get_pull(pr.number)  # Refrescar datos del PR
        nuevo = normalizar_titulo(pr.title, tp, alumnos)
        if pr.title != nuevo:
            print(f"+ #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}{"*" if pr.title != nuevo else ""}")
            print(f"    >>: {pr.title}")
            pr.edit(title=nuevo)
        else:
            print(f"- #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}")

    cols = sorted({c for a in alumnos for c in a.keys() if c.startswith("TP")})

    print(f"| fin {cols}")


def aceptar_prs_sin_conflictos():
    open_pulls = repo.get_pulls(state='open', sort='created', base='main')
    print("> Intentando merge de PRs sin conflictos:")
    for pr in open_pulls:
        pr = repo.get_pull(pr.number)       # Refrescar datos
        if pr.mergeable is None:
            time.sleep(5)
            pr = repo.get_pull(pr.number)   # Refrescar
        if pr.mergeable:
            try:
                pr.merge()
                print(f"- ✅ PR #{pr.number} mergeado: {pr.title}")
            except Exception as e:
                print(f"- ❌ Error al mergear PR #{pr.number}: {e}")
        elif pr.mergeable is False:
            print(f"- 👁️ PR #{pr.number} tiene conflictos: {pr.title}")
        else:
            print(f"- ⏳ Tiempo agotado para PR #{pr.number}: {pr.title}")
    print("| fin")

# Funciones
# 1. normalizar_pr -> renombra los PRs abiertos con formato estandar
# 2. merge_prs_sin_conflictos -> intenta mergear los PRs sin conflictos

alumnos = leer()
# normalizar_titulo_pr(tp=5, estado='open', alumnos=alumnos, min=190)
# cargar_github_user(alumnos)
# escribir(alumnos, "alumnos.md", orden_practicos=True)
# aceptar_prs_sin_conflictos()

averiguar_presentacion_practicos(alumnos)
escribir(alumnos, "alumnos-con-tp.md", orden_practicos=True)

# Cargar lista de alumnos en un DataFrame y mostrarlo como tabla
# df_alumnos = pd.DataFrame(alumnos)

# df_alumnos
# Out:
# > Leyendo ./alumnos.md...
# | 82 alumnos leídos.
# > Averiguando presentación de prácticos en 82 alumnos...
# ✓ PR #1: TP1 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #1: TP1 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #2: TP1 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #2: TP1 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #3: TP1 - 61627 - Juarez Fernandez, Lourdes Abril
# ✓ PR #3: TP1 - 61627 - Juarez Fernandez, Lourdes Abril
# x PR #4: TP1 - 61315 - Robles, Thiago (cerrado sin merge)
# x PR #4: TP1 - 61315 - Robles, Thiago (cerrado sin merge)
# ✓ PR #5: TP1 - 61315 - Robles, Thiago
# ✓ PR #5: TP1 - 61315 - Robles, Thiago
# ✓ PR #6: TP1 - 61911 - Llanos, Luciano
# ✓ PR #6: TP1 - 61911 - Llanos, Luciano
# ✓ PR #7: TP1 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #7: TP1 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #8: TP1 - 61579 - Gonzalo, Marti
# ✓ PR #8: TP1 - 61579 - Gonzalo, Marti
# ✓ PR #9: TP1 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #9: TP1 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #10: TP1 - 61033 - Quiroga, Jose Maria
# ✓ PR #10: TP1 - 61033 - Quiroga, Jose Maria
# ✓ PR #11: TP1 - 62555 - Verón, Matias Gabriel
# ✓ PR #11: TP1 - 62555 - Verón, Matias Gabriel
# ✓ PR #12: TP1 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #12: TP1 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #13: TP1 - 61032 - Moya, Mariano
# ✓ PR #13: TP1 - 61032 - Moya, Mariano
# ✓ PR #14: TP1 - 61271 - Donelli, Gerardo Exequiel
# ✓ PR #14: TP1 - 61271 - Donelli, Gerardo Exequiel
# ✓ PR #15: TP1 - 61719 - Amoedo, Pablo Isaias
# ✓ PR #15: TP1 - 61719 - Amoedo, Pablo Isaias
# ✓ PR #16: TP1 - 62172 - Mariana Aylen Salcedo
# ✓ PR #16: TP1 - 62172 - Mariana Aylen Salcedo
# x PR #17: TP1 - 61676 - Massey, Maximiliano (cerrado sin merge)
# x PR #17: TP1 - 61676 - Massey, Maximiliano (cerrado sin merge)
# ✓ PR #18: TP1 - 61319 - Carabajal, José Gabriel
# ✓ PR #18: TP1 - 61319 - Carabajal, José Gabriel
# ✓ PR #19: TP1 - 61139 - Gallo, María Matilde
# ✓ PR #19: TP1 - 61139 - Gallo, María Matilde
# ✓ PR #20: TP1 - 61037 - Paz, Rodrigo Federico
# ✓ PR #20: TP1 - 61037 - Paz, Rodrigo Federico
# ✓ PR #21: TP1 - 61445 - Martínez Campero, Santiago
# ✓ PR #21: TP1 - 61445 - Martínez Campero, Santiago
# ✓ PR #22: TP1 - 61046 - Ponce, Luz Micaela
# ✓ PR #22: TP1 - 61046 - Ponce, Luz Micaela
# ✓ PR #23: TP1 - 61335 - Leon, Lucas Ismael
# ✓ PR #23: TP1 - 61335 - Leon, Lucas Ismael
# ✓ PR #24: TP1 - 61478 - Soto, Antonella
# ✓ PR #24: TP1 - 61478 - Soto, Antonella
# ✓ PR #25: TP1 - 61200 - Gauna Serrano, Martin Javier
# ✓ PR #25: TP1 - 61200 - Gauna Serrano, Martin Javier
# ✓ PR #26: TP1 - 61626 - Diaz Londero, Sergio Gonzalo
# ✓ PR #26: TP1 - 61626 - Diaz Londero, Sergio Gonzalo
# ✓ PR #27: TP1 - 61240 - Timo, Hector Gabriel
# ✓ PR #27: TP1 - 61240 - Timo, Hector Gabriel
# ✓ PR #28: TP1 - 61167 - Giacobbe, Franco
# ✓ PR #28: TP1 - 61167 - Giacobbe, Franco
# x PR #29: TP1 - 61468 - Samaniego, Esteban Maximiliano (cerrado sin merge)
# x PR #29: TP1 - 61468 - Samaniego, Esteban Maximiliano (cerrado sin merge)
# ✓ PR #31: TP1 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #31: TP1 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #33: TP1 - 61725 - Villagra, Jorge Sebastián
# ✓ PR #33: TP1 - 61725 - Villagra, Jorge Sebastián
# ✓ PR #34: TP1 - 61450 - Jimenez Paz, Patricio Agustín
# ✓ PR #34: TP1 - 61450 - Jimenez Paz, Patricio Agustín
# ✓ PR #35: TP1 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #35: TP1 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #36: TP1 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #36: TP1 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #37: TP1 - 62175 - Quiroga, Marcela Noemi Quiroga
# ✓ PR #37: TP1 - 62175 - Quiroga, Marcela Noemi Quiroga
# ✓ PR #38: TP1 - 61473 - Lagoria Garcia, Tomás Gustavo
# ✓ PR #38: TP1 - 61473 - Lagoria Garcia, Tomás Gustavo
# ✓ PR #39: TP1 - 61565 - Carrizo, Mauro
# ✓ PR #39: TP1 - 61565 - Carrizo, Mauro
# ✓ PR #40: TP1 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #40: TP1 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #41: TP1 - 54911 - Jatib, Rodrigo Gabriel
# ✓ PR #41: TP1 - 54911 - Jatib, Rodrigo Gabriel
# ✓ PR #42: TP1 - 61667 - Acosta, Maira
# ✓ PR #42: TP1 - 61667 - Acosta, Maira
# x PR #43: TP1 - 62055 - Aumada, Aiquen Osvaldo (cerrado sin merge)
# x PR #43: TP1 - 62055 - Aumada, Aiquen Osvaldo (cerrado sin merge)
# ✓ PR #44: TP1 - 62053 - Herrera Palomino, Ivan Agustín
# ✓ PR #44: TP1 - 62053 - Herrera Palomino, Ivan Agustín
# ✓ PR #45: TP1 - 61338 - Morales, Juan Daniel
# ✓ PR #45: TP1 - 61338 - Morales, Juan Daniel
# ✓ PR #46: TP1 - 61115 - Ledesma, Santiago Esteban
# ✓ PR #46: TP1 - 61115 - Ledesma, Santiago Esteban
# ✓ PR #47: TP1 - 61073 - Gonzalez Chavez, Rodrigo
# ✓ PR #47: TP1 - 61073 - Gonzalez Chavez, Rodrigo
# ✓ PR #48: TP1 - 61028 - Ponce, Rodrigo Exequiel
# ✓ PR #48: TP1 - 61028 - Ponce, Rodrigo Exequiel
# ✓ PR #49: TP1 - 61129 - Tello, Abril María Agosti
# ✓ PR #49: TP1 - 61129 - Tello, Abril María Agosti
# ✓ PR #50: TP1 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #50: TP1 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #51: TP1 - 61805 - Jerez, Tomás
# ✓ PR #51: TP1 - 61805 - Jerez, Tomás
# ✓ PR #52: TP1 - 61136 - Sosa, Oscar Ignacio
# ✓ PR #52: TP1 - 61136 - Sosa, Oscar Ignacio
# ✓ PR #53: TP1 - 61120 - Guerrero, Ana Sofía
# ✓ PR #53: TP1 - 61120 - Guerrero, Ana Sofía
# ✓ PR #54: TP1 - 61113 - Oríz Caballero, Juan José
# ✓ PR #54: TP1 - 61113 - Oríz Caballero, Juan José
# ✓ PR #55: TP1 - 61150 - Molina Navarro, Juan Martin
# ✓ PR #55: TP1 - 61150 - Molina Navarro, Juan Martin
# ✓ PR #56: TP1 - 61198 - Ferreyra Appas, Santiago Nicolas
# ✓ PR #56: TP1 - 61198 - Ferreyra Appas, Santiago Nicolas
# ✓ PR #57: TP1 - 61472 - Diaz, Julieta Camila
# ✓ PR #57: TP1 - 61472 - Diaz, Julieta Camila
# ✓ PR #58: TP1 - 62263 - Orellana, José Augusto
# ✓ PR #58: TP1 - 62263 - Orellana, José Augusto
# ✓ PR #59: TP1 - 61248 - Palma Collado, Nahuel
# ✓ PR #59: TP1 - 61248 - Palma Collado, Nahuel
# ✓ PR #60: TP1 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #60: TP1 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #61: TP1 - 61551 - Diaz Valdez, Ignacio
# ✓ PR #61: TP1 - 61551 - Diaz Valdez, Ignacio
# ✓ PR #62: TP1 - 62318 - Quiroga Castro, Lisandro
# ✓ PR #62: TP1 - 62318 - Quiroga Castro, Lisandro
# ✓ PR #63: TP1 - 61818 - Lopez, Tisera Gaston
# ✓ PR #63: TP1 - 61818 - Lopez, Tisera Gaston
# ✓ PR #64: TP1 - 61141 - Di Clemente, Maria Antonela
# ✓ PR #64: TP1 - 61141 - Di Clemente, Maria Antonela
# ✓ PR #65: TP1 - 62093 - Frias Silva, Juan Segundo
# ✓ PR #65: TP1 - 62093 - Frias Silva, Juan Segundo
# ✓ PR #66: TP2 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #66: TP2 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #67: TP2 - 61200 - Gauna Serrano, Martin Javier
# ✓ PR #67: TP2 - 61200 - Gauna Serrano, Martin Javier
# ✓ PR #68: TP2 - 61579 - Gonzalo, Marti
# ✓ PR #68: TP2 - 61579 - Gonzalo, Marti
# ✓ PR #69: TP2 - 61315 - Robles, Thiago
# ✓ PR #69: TP2 - 61315 - Robles, Thiago
# ✓ PR #70: TP2 - 61719 - Amoedo, Pablo Isaias
# ✓ PR #70: TP2 - 61719 - Amoedo, Pablo Isaias
# ✓ PR #71: TP2 - 61271 - Donelli, Gerardo Exequiel
# ✓ PR #71: TP2 - 61271 - Donelli, Gerardo Exequiel
# ✓ PR #72: TP2 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #72: TP2 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #73: TP2 - 61338 - Morales, Juan Daniel
# ✓ PR #73: TP2 - 61338 - Morales, Juan Daniel
# ✓ PR #74: TP1 - 61203 - Acevedo Costello, Juan Ignacio
# ✓ PR #74: TP1 - 61203 - Acevedo Costello, Juan Ignacio
# ✓ PR #75: TP2 - 61203 - Acevedo Costello, Juan Ignacio
# ✓ PR #75: TP2 - 61203 - Acevedo Costello, Juan Ignacio
# ✓ PR #76: TP2 - 61073 - Gonzalez Chavez, Rodrigo
# ✓ PR #76: TP2 - 61073 - Gonzalez Chavez, Rodrigo
# ✓ PR #77: TP2 - 61033 - Quiroga, Jose Maria
# ✓ PR #77: TP2 - 61033 - Quiroga, Jose Maria
# ✓ PR #78: TP2 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #78: TP2 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #79: TP2 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #79: TP2 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #80: TP2 - 61037 - Paz, Rodrigo Federico
# ✓ PR #80: TP2 - 61037 - Paz, Rodrigo Federico
# ✓ PR #81: TP2 - 61240 - Timo, Hector Gabriel
# ✓ PR #81: TP2 - 61240 - Timo, Hector Gabriel
# ✓ PR #82: TP2 - 61626 - Diaz Londero, Sergio Gonzalo
# ✓ PR #82: TP2 - 61626 - Diaz Londero, Sergio Gonzalo
# ✓ PR #83: TP2 - 61167 - Giacobbe, Franco
# ✓ PR #83: TP2 - 61167 - Giacobbe, Franco
# ✓ PR #84: TP2 - 62093 - Frias Silva, Juan Segundo
# ✓ PR #84: TP2 - 62093 - Frias Silva, Juan Segundo
# ✓ PR #85: TP2 - 61473 - Lagoria Garcia, Tomás Gustavo
# ✓ PR #85: TP2 - 61473 - Lagoria Garcia, Tomás Gustavo
# ✓ PR #86: TP2 - 61624 - Godoy, Alan
# ✓ PR #86: TP2 - 61624 - Godoy, Alan
# ✓ PR #87: TP2 - 62055 - Aumada, Aiquen Osvaldo
# ✓ PR #87: TP2 - 62055 - Aumada, Aiquen Osvaldo
# ✓ PR #88: TP2 - 61445 - Martínez Campero, Santiago
# ✓ PR #88: TP2 - 61445 - Martínez Campero, Santiago
# ✓ PR #89: TP2 - 62053 - Herrera Palomino, Ivan Agustín
# ✓ PR #89: TP2 - 62053 - Herrera Palomino, Ivan Agustín
# ✓ PR #90: TP2 - 61198 - Ferreyra Appas, Santiago Nicolas
# ✓ PR #90: TP2 - 61198 - Ferreyra Appas, Santiago Nicolas
# ✓ PR #91: TP2 - 61627 - Juarez Fernandez, Lourdes Abril
# ✓ PR #91: TP2 - 61627 - Juarez Fernandez, Lourdes Abril
# ✓ PR #92: TP2 - 61136 - Sosa, Oscar Ignacio
# ✓ PR #92: TP2 - 61136 - Sosa, Oscar Ignacio
# ✓ PR #93: TP2 - 62555 - Verón, Matias Gabriel
# ✓ PR #93: TP2 - 62555 - Verón, Matias Gabriel
# ✓ PR #94: TP2 - 61911 - Llanos, Luciano
# ✓ PR #94: TP2 - 61911 - Llanos, Luciano
# ✓ PR #95: TP2 - 61046 - Ponce, Luz Micaela
# ✓ PR #95: TP2 - 61046 - Ponce, Luz Micaela
# ✓ PR #96: TP2 - 61335 - Leon, Lucas Ismael
# ✓ PR #96: TP2 - 61335 - Leon, Lucas Ismael
# ✓ PR #97: TP2 - 61115 - Ledesma, Santiago Esteban
# ✓ PR #97: TP2 - 61115 - Ledesma, Santiago Esteban
# x PR #98: TP1 - 61150 - Molina Navarro, Juan Martin (cerrado sin merge)
# x PR #98: TP1 - 61150 - Molina Navarro, Juan Martin (cerrado sin merge)
# ✓ PR #99: TP2 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #99: TP2 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #100: TP2 - 61478 - Soto, Antonella
# ✓ PR #100: TP2 - 61478 - Soto, Antonella
# ✓ PR #101: TP2 - 61084 - Ramirez, Leonardo
# ✓ PR #101: TP2 - 61084 - Ramirez, Leonardo
# ✓ PR #102: TP2 - 61818 - Lopez, Tisera Gaston
# ✓ PR #102: TP2 - 61818 - Lopez, Tisera Gaston
# ✓ PR #103: TP2 - 61725 - Villagra, Jorge Sebastián
# ✓ PR #103: TP2 - 61725 - Villagra, Jorge Sebastián
# x PR #104: TP2 - 61468 - MaxiSama12 (cerrado sin merge)
# x PR #104: TP2 - 61468 - MaxiSama12 (cerrado sin merge)
# ✓ PR #105: TP2 - 61028 - Ponce, Rodrigo Exequiel
# ✓ PR #105: TP2 - 61028 - Ponce, Rodrigo Exequiel
# ✓ PR #106: TP2 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #106: TP2 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #107: TP2 - 62263 - Orellana, José Augusto
# ✓ PR #107: TP2 - 62263 - Orellana, José Augusto
# ✓ PR #108: TP2 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #108: TP2 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #109: TP2 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #109: TP2 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #110: TP2 - 61676 - Massey, Maximiliano
# ✓ PR #110: TP2 - 61676 - Massey, Maximiliano
# ✓ PR #111: TP2 - 61113 - Oríz Caballero, Juan José
# ✓ PR #111: TP2 - 61113 - Oríz Caballero, Juan José
# ✓ PR #112: TP2 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #112: TP2 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #113: TP2 - 61319 - Carabajal, José Gabriel
# ✓ PR #113: TP2 - 61319 - Carabajal, José Gabriel
# x PR #114: TP2 - 61565 - Carrizo, Mauro (cerrado sin merge)
# x PR #114: TP2 - 61565 - Carrizo, Mauro (cerrado sin merge)
# ✓ PR #115: TP2 - 61150 - Molina Navarro, Juan Martin
# ✓ PR #115: TP2 - 61150 - Molina Navarro, Juan Martin
# ✓ PR #116: TP2 - 54911 - Jatib, Rodrigo Gabriel
# ✓ PR #116: TP2 - 54911 - Jatib, Rodrigo Gabriel
# x PR #117: TP2 - 62175 - Quiroga, Marcela Noemi Quiroga (cerrado sin merge)
# x PR #117: TP2 - 62175 - Quiroga, Marcela Noemi Quiroga (cerrado sin merge)
# ✓ PR #118: TP2 - 61032 - Moya, Mariano
# ✓ PR #118: TP2 - 61032 - Moya, Mariano
# ✓ PR #119: TP2 - 61450 - Jimenez Paz, Patricio Agustín
# ✓ PR #119: TP2 - 61450 - Jimenez Paz, Patricio Agustín
# ✓ PR #120: TP2 - 61141 - Di Clemente, Maria Antonela
# ✓ PR #120: TP2 - 61141 - Di Clemente, Maria Antonela
# ✓ PR #121: TP2 - 61139 - Gallo, María Matilde
# ✓ PR #121: TP2 - 61139 - Gallo, María Matilde
# ✓ PR #122: TP2 - 61248 - Palma Collado, Nahuel
# ✓ PR #122: TP2 - 61248 - Palma Collado, Nahuel
# ✓ PR #123: TP2 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #123: TP2 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #124: TP2 - 61667 - Acosta, Maira
# ✓ PR #124: TP2 - 61667 - Acosta, Maira
# ✓ PR #125: TP2 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #125: TP2 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #126: TP3 - 61129 - Tello, Abril María Agostina
# ✓ PR #126: TP3 - 61129 - Tello, Abril María Agostina
# ✓ PR #127: TP3 - 62555 - Verón, Matías Gabriel
# ✓ PR #127: TP3 - 62555 - Verón, Matías Gabriel
# ✓ PR #128: TP3 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #128: TP3 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #129: TP3 - 61911 - Llanos, Luciano
# ✓ PR #129: TP3 - 61911 - Llanos, Luciano
# ✓ PR #130: TP3 - 61139 - Gallo, María Matilde
# ✓ PR #130: TP3 - 61139 - Gallo, María Matilde
# ✓ PR #131: TP3 - 61046 - Ponce, Luz Micaela
# ✓ PR #131: TP3 - 61046 - Ponce, Luz Micaela
# ✓ PR #132: TP3 - 61338 - Morales, Juan Daniel
# ✓ PR #132: TP3 - 61338 - Morales, Juan Daniel
# ✓ PR #133: TP3 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #133: TP3 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #134: TP3 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #134: TP3 - 61572 - Parrado Navarrete, Alex Daniel
# ✓ PR #135: TP3 - 61167 - Giacobbe, Franco
# ✓ PR #135: TP3 - 61167 - Giacobbe, Franco
# ✓ PR #136: TP3 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #136: TP3 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #137: TP3 - 61315 - Robles, Thiago
# ✓ PR #137: TP3 - 61315 - Robles, Thiago
# ✓ PR #138: TP3 - 62093 - Frías Silva, Juan Segundo
# ✓ PR #138: TP3 - 62093 - Frías Silva, Juan Segundo
# ✓ PR #139: TP3 - 61626 - Díaz Londero, Sergio Gonzalo
# ✓ PR #139: TP3 - 61626 - Díaz Londero, Sergio Gonzalo
# ✓ PR #140: TP3 - 61150 - Molina Navarro, Juan Martín
# ✓ PR #230: TP4 - 61084 - Ramírez, Leonardo
# ✓ PR #230: TP4 - 61084 - Ramírez, Leonardo
# ✓ PR #231: TP4 - 61450 - Jiménez Paz, Patricio Agustín
# ✓ PR #231: TP4 - 61450 - Jiménez Paz, Patricio Agustín
# ✓ PR #232: TP4 - 61993 - Medina, Juan Ignacio
# ✓ PR #232: TP4 - 61993 - Medina, Juan Ignacio
# ✓ PR #233: TP4 - 61113 - Oríz Caballero, Juan José
# ✓ PR #233: TP4 - 61113 - Oríz Caballero, Juan José
# ✓ PR #234: TP4 - 61167 - Giacobbe, Franco
# ✓ PR #234: TP4 - 61167 - Giacobbe, Franco
# ✓ PR #235: TP4 - 61565 - Carrizo, Mauro
# ✓ PR #235: TP4 - 61565 - Carrizo, Mauro
# ✓ PR #236: TP4 - 62175 - Quiroga, Marcela Noemí
# ✓ PR #236: TP4 - 62175 - Quiroga, Marcela Noemí
# ✓ PR #237: TP4 - 62053 - Herrera Palomino, Iván Agustín
# ✓ PR #237: TP4 - 62053 - Herrera Palomino, Iván Agustín
# ✓ PR #238: TP4 - 61032 - Moya, Mariano
# ✓ PR #238: TP4 - 61032 - Moya, Mariano
# ✓ PR #239: TP5 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #239: TP5 - 61096 - Suárez Vece, Leandro Andrés
# x PR #240: TP4 - 62093 - frias silva juan segundo (cerrado sin merge)
# x PR #240: TP4 - 62093 - frias silva juan segundo (cerrado sin merge)
# ✓ PR #241: TP5 - 62555 - Verón, Matías Gabriel
# ✓ PR #241: TP5 - 62555 - Verón, Matías Gabriel
# ✓ PR #242: TP5 - 61626 - Díaz Londero, Sergio Gonzalo
# ✓ PR #242: TP5 - 61626 - Díaz Londero, Sergio Gonzalo
# ✓ PR #243: TP5 - 61129 - Tello, Abril María Agostina
# ✓ PR #243: TP5 - 61129 - Tello, Abril María Agostina
# ✓ PR #244: TP5 - 62263 - Orellana, José Augusto
# ✓ PR #244: TP5 - 62263 - Orellana, José Augusto
# ✓ PR #245: TP5 - 61315 - Robles, Thiago
# ✓ PR #245: TP5 - 61315 - Robles, Thiago
# ✓ PR #246: TP5 - 62055 - Ahumada, Aiquen Osvaldo
# ✓ PR #246: TP5 - 62055 - Ahumada, Aiquen Osvaldo
# ✓ PR #247: TP5 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #247: TP5 - 61131 - Agostino Colombres, Juan Manuel
# ✓ PR #248: TP5 - 61445 - Martínez Campero, Santiago
# ✓ PR #248: TP5 - 61445 - Martínez Campero, Santiago
# ✓ PR #249: TP5 - 61028 - Ponce, Rodrigo Exequíel
# ✓ PR #249: TP5 - 61028 - Ponce, Rodrigo Exequíel
# ✓ PR #250: TP5 - 61271 - Donelli, Gerardo Exequíel
# ✓ PR #250: TP5 - 61271 - Donelli, Gerardo Exequíel
# ✓ PR #251: TP5 - 61115 - Ledesma, Santiago Esteban
# ✓ PR #251: TP5 - 61115 - Ledesma, Santiago Esteban
# ✓ PR #252: TP5 - 61676 - Massey, Maximiliano
# ✓ PR #252: TP5 - 61676 - Massey, Maximiliano
# ✓ PR #253: TP5 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #253: TP5 - 61035 - Ledesma, Paulo Marcelo
# ✓ PR #254: TP5 - 54911 - Jatib, Rodrigo Gabriel
# ✓ PR #254: TP5 - 54911 - Jatib, Rodrigo Gabriel
# ✓ PR #255: TP5 - 61338 - Morales, Juan Daniel
# ✓ PR #255: TP5 - 61338 - Morales, Juan Daniel
# ✓ PR #256: TP5 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #256: TP5 - 61096 - Suárez Vece, Leandro Andrés
# ✓ PR #257: TP5 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #257: TP5 - 61221 - Duclós, Marcelo Ezequiel
# ✓ PR #258: TP5 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #258: TP5 - 61312 - Paz Berrondo, Lucas David
# ✓ PR #259: TP5 - 61141 - Di Clemente, María Antonela
# ✓ PR #259: TP5 - 61141 - Di Clemente, María Antonela
# ✓ PR #260: TP5 - 61139 - Gallo, María Matilde
# ✓ PR #260: TP5 - 61139 - Gallo, María Matilde
# ✓ PR #261: TP5 - 61141 - Di Clemente, María Antonela
# ✓ PR #261: TP5 - 61141 - Di Clemente, María Antonela
# ✓ PR #262: TP5 - 61139 - Gallo, María Matilde
# ✓ PR #262: TP5 - 61139 - Gallo, María Matilde
# ✓ PR #263: TP5 - 61240 - Timo, Héctor Gabriel
# ✓ PR #263: TP5 - 61240 - Timo, Héctor Gabriel
# ✓ PR #264: TP5 - 61319 - Carabajal, José Gabriel
# ✓ PR #264: TP5 - 61319 - Carabajal, José Gabriel
# ✓ PR #265: TP5 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #265: TP5 - 61236 - Drachenberg, Franco Eduardo
# ✓ PR #266: TP5 - 62555 - Verón, Matías Gabriel
# ✓ PR #266: TP5 - 62555 - Verón, Matías Gabriel
# ✓ PR #267: TP5 - 61319 - Carabajal, José Gabriel
# ✓ PR #267: TP5 - 61319 - Carabajal, José Gabriel
# ✓ PR #268: TP5 - 61627 - Juárez Fernández, Lourdes Abril
# ✓ PR #268: TP5 - 61627 - Juárez Fernández, Lourdes Abril
# ✓ PR #269: TP5 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #269: TP5 - 61197 - Romano, Alfredo Nicolás
# ✓ PR #270: TP5 - 61033 - Quiroga, José María
# ✓ PR #270: TP5 - 61033 - Quiroga, José María
# ✓ PR #271: TP5 - 61032 - Moya, Mariano
# ✓ PR #271: TP5 - 61032 - Moya, Mariano
# ✓ PR #272: TP5 - 61478 - Soto, Antonella
# ✓ PR #272: TP5 - 61478 - Soto, Antonella
# ✓ PR #273: TP5 - 61725 - Villagra, Jorge Sebastián
# ✓ PR #273: TP5 - 61725 - Villagra, Jorge Sebastián
# ✓ PR #274: TP5 - 61150 - Molina Navarro, Juan Martín
# ✓ PR #274: TP5 - 61150 - Molina Navarro, Juan Martín
# ✓ PR #275: TP5 - 61167 - Giacobbe, Franco
# ✓ PR #275: TP5 - 61167 - Giacobbe, Franco
# ✓ PR #276: TP5 - 62053 - Herrera Palomino, Iván Agustín
# ✓ PR #276: TP5 - 62053 - Herrera Palomino, Iván Agustín
# ✓ PR #277: TP5 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #277: TP5 - 61793 - Trujillo, Facundo Nahuel
# ✓ PR #278: TP5 - 61084 - Ramírez, Leonardo
# ✓ PR #278: TP5 - 61084 - Ramírez, Leonardo
# ✓ PR #279: TP5 - 61129 - Tello, Abril María Agostina
# ✓ PR #279: TP5 - 61129 - Tello, Abril María Agostina
# ✓ PR #280: TP5 - 61198 - Ferreyra Appas, Santiago Nicolás
# ✓ PR #280: TP5 - 61198 - Ferreyra Appas, Santiago Nicolás
# ✓ PR #281: TP5 - 61200 - Gauna Serrano, Martín Javier
# ✓ PR #281: TP5 - 61200 - Gauna Serrano, Martín Javier
# ✓ PR #282: TP5 - 61073 - González Chavez, Rodrigo
# ✓ PR #282: TP5 - 61073 - González Chavez, Rodrigo
# ✓ PR #283: TP5 - 61473 - Lagoria García, Tomás Gustavo
# ✓ PR #283: TP5 - 61473 - Lagoria García, Tomás Gustavo
# ✓ PR #284: TP5 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #284: TP5 - 61468 - Samaniego, Esteban Maximiliano
# ✓ PR #285: TP5 - 61037 - Paz, Rodrigo Federico
# ✓ PR #285: TP5 - 61037 - Paz, Rodrigo Federico
# ✓ PR #286: TP5 - 61667 - Acosta, Maira
# ✓ PR #286: TP5 - 61667 - Acosta, Maira
# ✓ PR #287: TP5 - 61046 - Ponce, Luz Micaela
# ✓ PR #287: TP5 - 61046 - Ponce, Luz Micaela
# ✓ PR #288: TP5 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #288: TP5 - 61794 - Lobo Campero, Hernán Ignacio
# ✓ PR #289: TP5 - 61818 - López Tisera, Gastón
# ✓ PR #289: TP5 - 61818 - López Tisera, Gastón
# ✓ PR #290: TP5 - 61551 - Díaz Valdez, Ignacio
# ✓ PR #290: TP5 - 61551 - Díaz Valdez, Ignacio
# ✓ PR #291: TP5 - 62318 - Quiroga Castro, Lisandro
# ✓ PR #291: TP5 - 62318 - Quiroga Castro, Lisandro
# ✓ PR #292: TP5 - 61993 - Medina, Juan Ignacio
# ✓ PR #292: TP5 - 61993 - Medina, Juan Ignacio
# ✓ PR #293: TP5 - 61565 - Carrizo, Mauro
# ✓ PR #293: TP5 - 61565 - Carrizo, Mauro
# ✓ PR #294: TP5 - 62175 - Quiroga, Marcela Noemí
# ✓ PR #294: TP5 - 62175 - Quiroga, Marcela Noemí
# ✓ PR #295: TP5 - 61911 - Llanos, Luciano
# ✓ PR #295: TP5 - 61911 - Llanos, Luciano
# ✓ PR #296: TP5 - 61335 - León, Lucas Ismael
# ✓ PR #296: TP5 - 61335 - León, Lucas Ismael
# ✓ PR #297: TP5 - 61248 - Palma Collado, Nahuel
# ✓ PR #297: TP5 - 61248 - Palma Collado, Nahuel
# ✓ PR #298: TP5 - 62093 - Frías Silva, Juan Segundo
# ✓ PR #298: TP5 - 62093 - Frías Silva, Juan Segundo
# x PR #299: tp 6 oriz caballero juan jose (cerrado sin merge)
# x PR #299: tp 6 oriz caballero juan jose (cerrado sin merge)
# ✓ PR #300: TP5 - 61113 - Oríz Caballero, Juan José
# ✓ PR #300: TP5 - 61113 - Oríz Caballero, Juan José
# ✓ PR #301: TP5 - 61450 - Jiménez Paz, Patricio Agustín
# ✓ PR #301: TP5 - 61450 - Jiménez Paz, Patricio Agustín
# ✓ PR #302: TP5 - 61626 - Díaz Londero, Sergio Gonzalo
# |
# > Escribiendo alumnos-con-tp.md...
# | 82 alumnos guardados
# ✓ PR #302: TP5 - 61626 - Díaz Londero, Sergio Gonzalo
# |
# > Escribiendo alumnos-con-tp.md...
# | 82 alumnos guardados
# [{'legajo': '62171',
#   'nombre': 'Ballespin, Cristián',
#   'telefono': '(381) 604-5734',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '99001',
#   'nombre': 'Branda, César',
#   'telefono': '(381) 212-6932',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61337',
#   'nombre': 'Díaz, Christian Gabriel',
#   'telefono': '(381) 571-4797',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61813',
#   'nombre': 'Figueroa, Manuel',
#   'telefono': '(381) 544-2423',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61463',
#   'nombre': 'González, Nicolas (oyente)',
#   'telefono': '(381) 588-3047',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61463',
#   'nombre': 'González, Vladimir',
#   'telefono': '(381) 419-4154',
#   'github': '',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61993',
#   'nombre': 'Medina, Juan Ignacio',
#   'telefono': '(381) 517-1937',
#   'github': 'Soulmain1',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61084',
#   'nombre': 'Ramírez, Leonardo',
#   'telefono': '(381) 348-9132',
#   'github': 'Leoramirez777',
#   'comision': 'C1',
#   'TP1': '🔴',
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61551',
#   'nombre': 'Díaz Valdez, Ignacio',
#   'telefono': '(381) 695-8566',
#   'github': 'IgnacioDiazV',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61120',
#   'nombre': 'Guerrero, Ana Sofía',
#   'telefono': '(381) 418-1564',
#   'github': 'AnaSofi03',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61805',
#   'nombre': 'Jerez, Tomás',
#   'telefono': '(381) 338-0186',
#   'github': 'ElTommmy',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '62318',
#   'nombre': 'Quiroga Castro, Lisandro',
#   'telefono': '(381) 390-9133',
#   'github': 'Lisandro-18',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61472',
#   'nombre': 'Díaz, Julieta Camila',
#   'telefono': '(381) 652-9981',
#   'github': 'juliidiiaz04',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61131',
#   'nombre': 'Agostino Colombres, Juan Manuel',
#   'telefono': '(381) 684-8399',
#   'github': 'JuanmaAgostino',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61565',
#   'nombre': 'Carrizo, Mauro',
#   'telefono': '(381) 610-8745',
#   'github': 'DarkoDarkShadow',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🟢',
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61236',
#   'nombre': 'Drachenberg, Franco Eduardo',
#   'telefono': '(381) 670-8708',
#   'github': 'FDrach',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61198',
#   'nombre': 'Ferreyra Appas, Santiago Nicolás',
#   'telefono': '(381) 648-4455',
#   'github': 'Ercutt',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61167',
#   'nombre': 'Giacobbe, Franco',
#   'telefono': '(381) 588-0371',
#   'github': 'frandg47',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61073',
#   'nombre': 'González Chavez, Rodrigo',
#   'telefono': '(381) 624-3000',
#   'github': 'rodrigogc21',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '54911',
#   'nombre': 'Jatib, Rodrigo Gabriel',
#   'telefono': '(381) 655-3096',
#   'github': 'RodrigoJatib',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61035',
#   'nombre': 'Ledesma, Paulo Marcelo',
#   'telefono': '(381) 664-8356',
#   'github': 'pauloled',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61115',
#   'nombre': 'Ledesma, Santiago Esteban',
#   'telefono': '(381) 346-3696',
#   'github': 'santled',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61335',
#   'nombre': 'León, Lucas Ismael',
#   'telefono': '(381) 609-7898',
#   'github': 'LuquitasLeon',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61911',
#   'nombre': 'Llanos, Luciano',
#   'telefono': '(381) 325-9224',
#   'github': 'LucianoLlanos',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61338',
#   'nombre': 'Morales, Juan Daniel',
#   'telefono': '(381) 665-5296',
#   'github': 'JuanMo17',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61046',
#   'nombre': 'Ponce, Luz Micaela',
#   'telefono': '(381) 664-7165',
#   'github': 'Mica8p',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61033',
#   'nombre': 'Quiroga, José María',
#   'telefono': '(11) 2399-7675',
#   'github': 'jose-qui',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '62175',
#   'nombre': 'Quiroga, Marcela Noemí',
#   'telefono': '(381) 593-8430',
#   'github': 'Marce-Quiroga',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': '🟢',
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61315',
#   'nombre': 'Robles, Thiago',
#   'telefono': '(381) 344-7120',
#   'github': 'T1T0Dev',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61468',
#   'nombre': 'Samaniego, Esteban Maximiliano',
#   'telefono': '(381) 679-6586',
#   'github': 'MaxiSama12',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61240',
#   'nombre': 'Timo, Héctor Gabriel',
#   'telefono': '(381) 343-0992',
#   'github': 'GabrielTimo006',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61725',
#   'nombre': 'Villagra, Jorge Sebastián',
#   'telefono': '(381) 594-1635',
#   'github': 'JorgeVillagraa',
#   'comision': 'C1',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61214',
#   'nombre': 'Collazos Cortez, Máximo Alberto',
#   'telefono': '(381) 350-5275',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61730',
#   'nombre': 'Díaz, Antonio',
#   'telefono': '(381) 392-6461',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61720',
#   'nombre': 'Fernández, Luciano',
#   'telefono': '(381) 586-7891',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61352',
#   'nombre': 'García Moya, José Ignacio',
#   'telefono': '(381) 638-9006',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61624',
#   'nombre': 'Godoy, Alan',
#   'telefono': '(381) 574-4877',
#   'github': 'AlanG46',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': 1,
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61595',
#   'nombre': 'González Patti, Valentín',
#   'telefono': '(381) 655-9195',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61562',
#   'nombre': 'Helguera, Agustina Elizabeth',
#   'telefono': '(381) 694-9619',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61956',
#   'nombre': 'Leglisé, Laureano',
#   'telefono': '(261) 468-9809',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61679',
#   'nombre': 'Lobo Barrera, María de los Ángeles',
#   'telefono': '(381) 677-0639',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61581',
#   'nombre': 'Naim, Federico Paz',
#   'telefono': '(381) 353-0060',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61059',
#   'nombre': 'Palavecino, Fabricio Gastón',
#   'telefono': '(381) 666-6103',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61862',
#   'nombre': 'Zerda, Thomas',
#   'telefono': '(381) 333-0962',
#   'github': '',
#   'comision': 'C3',
#   'TP1': '🔴',
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '62172',
#   'nombre': 'Salcedo, Mariana Aylén',
#   'telefono': '(381) 466-9695',
#   'github': 'marianasalcedo22',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': '🔴',
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61129',
#   'nombre': 'Tello, Abril María Agostina',
#   'telefono': '(381) 447-2483',
#   'github': 'abriltello',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': '🔴',
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61203',
#   'nombre': 'Acevedo Costello, Juan Ignacio',
#   'telefono': '(381) 388-7804',
#   'github': 'Ignacioacevedoo',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61667',
#   'nombre': 'Acosta, Maira',
#   'telefono': '(381) 562-8162',
#   'github': 'maira-acostaa',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '62055',
#   'nombre': 'Ahumada, Aiquen Osvaldo',
#   'telefono': '(381) 419-9202',
#   'github': 'aiquen7',
#   'comision': 'C3',
#   'TP1': '🟢',
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61719',
#   'nombre': 'Amoedo, Pablo Isaías',
#   'telefono': '(381) 463-6126',
#   'github': 'Kryfter',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 0},
#  {'legajo': '61319',
#   'nombre': 'Carabajal, José Gabriel',
#   'telefono': '(381) 319-2680',
#   'github': '7GabrielC',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61141',
#   'nombre': 'Di Clemente, María Antonela',
#   'telefono': '(381) 398-3935',
#   'github': 'antodiclemente',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61271',
#   'nombre': 'Donelli, Gerardo Exequíel',
#   'telefono': '(381) 514-3223',
#   'github': 'GerardoExe',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61221',
#   'nombre': 'Duclós, Marcelo Ezequiel',
#   'telefono': '(381) 551-4353',
#   'github': 'EzeDuclos',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61626',
#   'nombre': 'Díaz Londero, Sergio Gonzalo',
#   'telefono': '(381) 604-6547',
#   'github': 'Gonzalo-diazz',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '62093',
#   'nombre': 'Frías Silva, Juan Segundo',
#   'telefono': '(381) 415-8753',
#   'github': 'juansefriass',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61139',
#   'nombre': 'Gallo, María Matilde',
#   'telefono': '(381) 333-4836',
#   'github': 'matildegallom',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61200',
#   'nombre': 'Gauna Serrano, Martín Javier',
#   'telefono': '(381) 389-2631',
#   'github': 'MartinGS8',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61579',
#   'nombre': 'Gonzalo, Martín',
#   'telefono': '(381) 418-6882',
#   'github': 'Lived18',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 0},
#  {'legajo': '62053',
#   'nombre': 'Herrera Palomino, Iván Agustín',
#   'telefono': '(381) 697-0643',
#   'github': 'ivanagustinherrera',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61450',
#   'nombre': 'Jiménez Paz, Patricio Agustín',
#   'telefono': '(381) 388-2674',
#   'github': 'patricio-jp',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61627',
#   'nombre': 'Juárez Fernández, Lourdes Abril',
#   'telefono': '(381) 647-9914',
#   'github': 'LourdesFernandez1',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61473',
#   'nombre': 'Lagoria García, Tomás Gustavo',
#   'telefono': '(381) 357-7724',
#   'github': 'tomaslago27',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61794',
#   'nombre': 'Lobo Campero, Hernán Ignacio',
#   'telefono': '(381) 590-6461',
#   'github': 'lobohhernan',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61818',
#   'nombre': 'López Tisera, Gastón',
#   'telefono': '(381) 523-5887',
#   'github': 'gastonlopezt',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61445',
#   'nombre': 'Martínez Campero, Santiago',
#   'telefono': '(381) 646-6685',
#   'github': 'SantiCampero',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61676',
#   'nombre': 'Massey, Maximiliano',
#   'telefono': '(381) 359-9941',
#   'github': 'EPILONgaga',
#   'comision': 'C3',
#   'TP1': '🟢',
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61150',
#   'nombre': 'Molina Navarro, Juan Martín',
#   'telefono': '(381) 644-3413',
#   'github': 'JuanMolinaNavarro',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61032',
#   'nombre': 'Moya, Mariano',
#   'telefono': '(381) 670-1164',
#   'github': 'mariano-moya',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '62263',
#   'nombre': 'Orellana, José Augusto',
#   'telefono': '(381) 339-2050',
#   'github': 'Jaodem',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61113',
#   'nombre': 'Oríz Caballero, Juan José',
#   'telefono': '(381) 631-7223',
#   'github': 'JuanchoCab',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61248',
#   'nombre': 'Palma Collado, Nahuel',
#   'telefono': '(381) 674-7012',
#   'github': 'Nahu333',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61572',
#   'nombre': 'Parrado Navarrete, Alex Daniel',
#   'telefono': '(381) 409-5039',
#   'github': 'AlexDaniel28',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 0},
#  {'legajo': '61312',
#   'nombre': 'Paz Berrondo, Lucas David',
#   'telefono': '(381) 341-4321',
#   'github': 'Lucasdxvid',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61037',
#   'nombre': 'Paz, Rodrigo Federico',
#   'telefono': '(381) 637-6461',
#   'github': 'Rodrigopz52',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61028',
#   'nombre': 'Ponce, Rodrigo Exequíel',
#   'telefono': '(381) 569-0318',
#   'github': 'rodrikapo12',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61197',
#   'nombre': 'Romano, Alfredo Nicolás',
#   'telefono': '(381) 648-8513',
#   'github': 'NicoRomano904',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61136',
#   'nombre': 'Sosa, Oscar Ignacio',
#   'telefono': '(381) 528-9145',
#   'github': 'Oscar40997',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 0,
#   'TP5': 0},
#  {'legajo': '61478',
#   'nombre': 'Soto, Antonella',
#   'telefono': '(387) 517-0010',
#   'github': 'anto210',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '61096',
#   'nombre': 'Suárez Vece, Leandro Andrés',
#   'telefono': '(381) 512-6476',
#   'github': 'leandroVece',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0},
#  {'legajo': '61793',
#   'nombre': 'Trujillo, Facundo Nahuel',
#   'telefono': '(381) 206-2084',
#   'github': 'FacundoTrujillo',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP4': 1,
#   'TP5': 1},
#  {'legajo': '62555',
#   'nombre': 'Verón, Matías Gabriel',
#   'telefono': '(381) 519-6654',
#   'github': 'MatiasVeron12503',
#   'comision': 'C3',
#   'TP1': 1,
#   'TP2': 1,
#   'TP3': 1,
#   'TP5': 1,
#   'TP4': 0}]

# %%
def descargar_avatar_github(username: str, destino: str | Path = "./avatars", nombre_archivo: str | None = None, token: str | None = None, use_direct_url: bool = True) -> Path:
    destino = Path(destino)
    destino.mkdir(parents=True, exist_ok=True)

    base = nombre_archivo if nombre_archivo else username

    def _guardar(img_resp: requests.Response, ruta_base: Path) -> Path:
        # Elegir extensión por Content-Type
        content_type = img_resp.headers.get("Content-Type", "").lower()
        _ext = ".jpg"
        if "png" in content_type:
            _ext = ".png"
        elif any(x in content_type for x in ["jpeg", "jpg"]):
            _ext = ".jpg"
        elif "gif" in content_type:
            _ext = ".gif"
        destino_archivo = ruta_base.with_suffix(_ext)
        with open(destino_archivo, "wb") as f:
            for chunk in img_resp.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print(f"Avatar guardado en: {destino_archivo}")
        return destino_archivo

    # 1) Intentar descargar directamente desde la URL pública del avatar (sin consumir API core)
    if use_direct_url:
        direct_url = f"https://github.com/{username}.png"
        try:
            img_resp = requests.get(direct_url, stream=True, timeout=30)
            if img_resp.status_code == 200:
                return _guardar(img_resp, destino / base)
            else:
                print(f"No se pudo usar URL directa ({img_resp.status_code}), se intentará API.")
        except Exception as e:
            print(f"Fallo URL directa: {e}. Se intentará API.")

    # 2) Consultar API para obtener avatar_url (con token si está disponible)
    token = token or os.getenv("GITHUB_TOKEN")
    headers = {"Accept": "application/vnd.github+json"}
    if token:
        headers["Authorization"] = f"Bearer {token}"

    url = f"https://api.github.com/users/{username}"
    resp = requests.get(url, headers=headers, timeout=20)
    if resp.status_code == 403:
        # Rate limit excedido
        reset = resp.headers.get("X-RateLimit-Reset")
        if reset and reset.isdigit():
            wait = max(0, int(reset) - int(time.time()) + 2)
            raise RuntimeError(f"Rate limit excedido. Reintentar en ~{wait}s o usar un token válido en GITHUB_TOKEN.")
        raise RuntimeError("Rate limit excedido. Configure GITHUB_TOKEN para aumentar el límite (hasta 5000/hora).")
    resp.raise_for_status()
    data = resp.json()
    avatar_url = data.get("avatar_url")
    if not avatar_url:
        raise RuntimeError(f"No se encontró avatar para el usuario: {username}")

    img_resp = requests.get(avatar_url, stream=True, timeout=30)
    img_resp.raise_for_status()
    return _guardar(img_resp, destino / base)


def bajar_avatars():
    descargados = []

    alumnos = leer()
    for alumno in alumnos:
        gh = (alumno.get('github') or "").strip("@ ")
        if not gh: continue
        destino = Path(carpeta(alumno))  # carpeta devuelve ../tp/<legajo> - <nombre>
        destino.mkdir(parents=True, exist_ok=True)
        nombre_base = str(alumno['legajo'])
        try:
            ruta = descargar_avatar_github(gh, destino=destino, nombre_archivo=nombre_base, use_direct_url=True)
            descargados.append(ruta)
            time.sleep(0.2)  # pequeño throttle para ser buen ciudadano
        except Exception as e:
            print(f"No se pudo bajar avatar de {gh} ({alumno['legajo']}): {e}")

    print(f"Avatares descargados: {len(descargados)}")
# Ejemplo individual:
bajar_avatars()
# descargar_avatar_github("alejandrodibattista")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 def descargar_avatar_github(username: str, destino: str | Path = "./avatars", nombre_archivo: str | None = None, token: str | None = None, use_direct_url: bool = True) -> Path:
#       2     destino = Path(destino)
#       3     destino.mkdir(parents=True, exist_ok=True)
#
# NameError: name 'Path' is not defined

# %%
# Extraer asistencias a partir de whatsapp exportado 
from datetime import datetime
import re



def extraer_asistencias(lineas, comision=None):
    patron = re.compile(r"^\[(\d{1,2}/\d{1,2}/\d{2}),\s*(\d{1,2}:\d{2}:\d{2})\]\s*(.*?):")
    
    registros = []
    for linea in lineas:
        linea = linea.strip()
        linea = linea.replace("‎", "")
        if not linea:
            continue
        if match := patron.match(linea):
            fecha_str, hora_str, nombre = match.groups()
            fecha = datetime.strptime(fecha_str, "%d/%m/%y").date()
            registros.append({"fecha": fecha.isoformat(), "hora": hora_str, "nombre": nombre, "comision": comision})
        else:
            print(f"No coincide: {linea}")

    return registros

def leer_chat(comision: int ):
    with open(f"./interno/chat/c{comision}.txt", "r", encoding="utf-8") as archivo:
        lineas = archivo.readlines()
    return extraer_asistencias(lineas, comision)

asistencias = []
asistencias += leer_chat(1)
asistencias += leer_chat(3)
asistencias
# Out:
# No coincide: mañana clase virtual!!
# No coincide: Le paso el link 5 minutos antes
# No coincide: los espero
# No coincide: 8:10 empezamos en punto empezamos
# No coincide: https://meet.google.com/mas-xuyd-var
# No coincide: Le paso el link para la case de hoy
# No coincide: https://meet.google.com/zuo-nhyp-vtk
# No coincide: https://meet.google.com/crh-sshj-ddd
# No coincide: Mañana habrá paro y, lamentablemente, me han pedido que no tengamos clase virtual.
# No coincide: Nos vemos el martes. ¡Que disfruten el día libre y cuídense!
# No coincide: Me dicen sus compañeros de la otra comision que mañana solo tendrían clases conmigo, que profe está de licencia
# No coincide: La comisión c1 y c3 compartimos horarios los jueves y viernes
# No coincide: Ellos me preguntan si podria ser clase virtual mañana...
# No coincide: Me podrían confirmar si la profe esta de licencia mañana?
# No coincide: Me acaban de confirmar que la profe de metodología sigue de licencia.
# No coincide: La otra comisión en la que enseño me pidió si la clase podria ser virtual.
# No coincide: Pero para poder darle clase virtual ambas comisiones deben estar de acuerdo…
# No coincide: Que prefieren… clase virtual o presencial…
# No coincide: Que prefieren...
# No coincide: OPCIÓN: Clase Virtual (19 votos)
# No coincide: OPCIÓN: Clase Presencia… (0 votos)
# No coincide: > Mañana clase virtual en el horario habitual.
# No coincide: Avisen a sus compañeros.
# No coincide: Le paso el link a la clase….
# No coincide: https://meet.google.com/nqs-nrxx-yxs
# No coincide: Comenzamos a 8:05 <Se editó este mensaje.>
# No coincide: Mañana NO hay clase virtual!!
# No coincide: Nos vemos el Jueves
# No coincide: https://youtu.be/WGZmJ6BZbi4?si=CGpHVwlVl7uodM8m
# No coincide: https://examen-p1.netlify.app/
# No coincide: mañana hay clase virtual.
# No coincide: Le paso el link un rato antes.
# No coincide: Veo que algunos entraron y luego salieron….
# No coincide: El profe Politi me pidió si podíamos *unificar mañana las clases de las dos comisiones*. Tanto él como yo tenemos *C1 y C3 los martes*, en horarios alternados, y ambos grupos están viendo los mismos temas.
# No coincide: Así que *mañana martes, la clase de 8 a 10* la van a tener *con él* (también se los va a avisar), y *conmigo* tendremos la clase a partir de *las 10*.
# No coincide: El *enlace será el mismo de hoy*, pero igual se los voy a volver a enviar unos minutos antes de la clase.
# No coincide: ¡Los espero! 👋
# No coincide: https://meet.jit.si/programacion3
# No coincide: 10:10 comenzamos
# No coincide: https://asistencia-p4.netlify.app/
# No coincide: mañana clase virtual!!
# No coincide: Le paso el link 5 minutos antes
# No coincide: los espero
# No coincide: https://meet.google.com/uqp-ehhd-ner
# No coincide: https://meet.google.com/zvu-prqs-ffq
# No coincide: Disculpen la demora… esta en la otra comision.
# No coincide: https://meet.google.com/ona-xrav-zto
# No coincide: https://meet.google.com/ntz-temh-xrg
# No coincide: Mañana habrá paro y, lamentablemente, me han pedido que no tengamos clase virtual.
# No coincide: Nos vemos el martes. ¡Que disfruten el día libre y cuídense!
# No coincide: Ya que la profe esta de licencia y alguno de sus compañeros me solicitaron que la clase sea virtual…
# No coincide: Que prefieren… Clase Virtual o Presencial...
# No coincide: Que prefieren?
# No coincide: OPCIÓN: Clase Virtual (34 votos)
# No coincide: OPCIÓN: Clase Presencial (1 voto)
# No coincide: > Mañana clase virtual en el horario habitual.
# No coincide: Avisen a sus compañeros.
# No coincide: https://meet.google.com/dhq-zxiy-jaj
# No coincide: > Estimados colegas hoy 19/9  los alumnos de la facultad a través de la SAE tendrán jornada recreativa. Comuniquen a sus docentes  que pueden concurrir con los alumnos al campo de deportes o continuar con sus clases si lo consideran oportuno. Saludos
# No coincide: @⁨Oscar Ignacio Sosa⁩
# No coincide: Mañana NO hay clase virtual!!
# No coincide: Nos vemos el Jueves
# No coincide: https://youtu.be/9C03eaVuGZ0?si=r7BnU6Ijjdyl7vHd
# No coincide: Esta es la página para realizar los mini exámenes para conseguir los créditos.
# No coincide: https://examen-p1.netlify.app/
# No coincide: https://examen-p1.netlify.app/
# No coincide: mañana hay clase virtual.
# No coincide: Le paso el link un rato antes.
# No coincide: En minutos empezamos la clase de hoy
# No coincide: https://meet.jit.si/programacion3
# No coincide: https://meet.jit.si/programacion3
# No coincide: 10:10 comenzamos
# No coincide: https://asistencia-p4.netlify.app/
# [{'fecha': '2025-08-12', 'hora': '00:30:34', 'nombre': 'P4 C1', 'comision': 1},
#  {'fecha': '2025-08-12', 'hora': '00:25:04', 'nombre': 'Tú', 'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:23:37',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:23:55',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:23:56',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:19',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:21',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:42',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:42',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:43',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:45',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:45',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:49',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:24:51',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:25:04',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:25:10',
#   'nombre': 'Cristian Ballespin',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:26:11',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:26:21',
#   'nombre': '\u202a+54\xa09\xa03815\xa039‑0011\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:26:44',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:26:58',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:28:53',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:30:18',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:30:46',
#   'nombre': 'Manuel Figueroa',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:30:54',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:34:35',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:34:36',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:34:41',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:34:42',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:34:55',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:35:18',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:42:46',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:42:34',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:42:44',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:42:50',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:42:53',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:02',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:03',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:07',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:08',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:09',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:09',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:10',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:12',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:12',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:12',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:14',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:17',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:22',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:23',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:25',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:25',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:25',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:26',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:31',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:46',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:43:55',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '08:44:06',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '09:06:17',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '09:28:42',
#   'nombre': 'Cesar Branda',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '09:58:39',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-08-12',
#   'hora': '13:17:33',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:01',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:02',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:03',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:15',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:15',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:16',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:21',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:23',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:28',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:33',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:35',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:35',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:38',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:43',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:50',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:52',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:17:54',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:18:17',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:18:52',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:24:28',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:28:54',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:31:33',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:44:51',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '08:58:36',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-13',
#   'hora': '10:12:30',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:19',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:26',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:26',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:28',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:29',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:30',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:31',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:32',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:33',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:33',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:35',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:37',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:38',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:38',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:25:39',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:36:49',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:38:11',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:48:44',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '08:49:14',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-14',
#   'hora': '09:57:19',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:00:36',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:00:46',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:00:52',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:00:54',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:00:54',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:01',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:02',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:03',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:03',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:06',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:09',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:09',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:10',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:15',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:19',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:32',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:34',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:38',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:01:40',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:02:09',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:02:16',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:02:16',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:02:43',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-20',
#   'hora': '10:04:25',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:19:10',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:19:37',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:19:41',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:20:20',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:20:27',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '08:20:33',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:13',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:16',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:21',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:22',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:23',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:24',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:25',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:26',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:31',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:32',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:36',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:49',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:52',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:05:55',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:06:08',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:06:43',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:06:47',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:07:02',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:07:02',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:08:01',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:09:14',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:11:11',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:11:31',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-21',
#   'hora': '10:13:23',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:42',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:43',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:49',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:49',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:51',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:52',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:53',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:07:59',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:00',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:00',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:00',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:01',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:05',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:05',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:13',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:26',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:29',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:37',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:08:37',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:09:22',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-22',
#   'hora': '10:10:42',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-24',
#   'hora': '19:26:20',
#   'nombre': '\u202a+54\xa09\xa03815\xa039‑0011\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-25',
#   'hora': '23:36:55',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-25',
#   'hora': '23:36:55',
#   'nombre': '\u202a+54\xa09\xa03815\xa067‑4692\u202c',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:46',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:50',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:51',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:51',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:54',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:54',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:54',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:56',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:03:56',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:01',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:06',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:12',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:13',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:19',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:50',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:52',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:04:53',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:16:00',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:18:17',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:20:47',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:20:55',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-26',
#   'hora': '10:21:25',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '09:16:19',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:11:52',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:11:54',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:11:55',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:11:57',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:03',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:04',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:05',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:08',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:15',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:12:22',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:15:04',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:15:06',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:15:15',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:15:47',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:20:35',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:21:11',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:29:36',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:29:45',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:45:26',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-08-27',
#   'hora': '10:49:50',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:16:49',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:16:59',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:00',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:04',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:05',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:09',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:31',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:17:31',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:18:02',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:18:17',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:19:01',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:19:21',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:19:35',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:20:10',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:20:39',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:21:47',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:21:48',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:22:30',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:23:19',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:23:35',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:25:16',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:25:41',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:26:02',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:37:01',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:49:48',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-08-28',
#   'hora': '10:51:51',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:03',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:06',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:12',
#   'nombre': '~\u202f.',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:12',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:24',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:27',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:29',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:39',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:42',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:47',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:54',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:04:57',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:05:03',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:05:14',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:05:14',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:06:27',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:08:29',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:08:32',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:12:10',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:12:32',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:12:37',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:12:56',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-08-29',
#   'hora': '10:21:55',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:57:54',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:57:58',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:58:10',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:58:14',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:58:40',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:58:52',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:59:00',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '09:59:10',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:00:10',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:00:32',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:01:54',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:02:22',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:02:47',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:06:16',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:06:26',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:06:43',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:06:56',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:06:57',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:07:08',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:19:41',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-02',
#   'hora': '10:23:25',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:05:53',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:05:56',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:05:56',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:06:05',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:06:08',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:06:11',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:06:29',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:06:42',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:07:12',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:07:38',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:07:45',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:08:16',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:09:22',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:10:20',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:16:19',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:18:49',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:44:15',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:45:27',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '10:46:42',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '18:03:09',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-03',
#   'hora': '20:14:32',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '08:01:21',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '08:02:15',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '09:06:26',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '09:52:50',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:06:36',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:06:48',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:06:53',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:06:53',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:00',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:19',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:21',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:26',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:29',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:07:49',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:08:19',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:08:27',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:09:12',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:11:54',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:21:30',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:21:57',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:24:44',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:31:04',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-09-04',
#   'hora': '10:41:21',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '08:04:33',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '08:04:42',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '09:08:24',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:02',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:19',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:34',
#   'nombre': 'Rodrigo Gabriel Jatib',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:38',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:39',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:54',
#   'nombre': 'Julieta Camila Diaz',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:09:58',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:10:03',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:10:24',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:10:25',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:10:32',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:11:23',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:12:02',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:14:38',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:33:45',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:34:22',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:39:07',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:43:07',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '10:48:27',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '11:08:06',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '11:32:38',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-05',
#   'hora': '11:56:24',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:26',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:34',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:41',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:43',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:43',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:47',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:47',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:51',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:11:52',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:12:18',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:12:21',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:12:34',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:13:29',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:13:51',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:14:12',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:14:22',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:14:29',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-09',
#   'hora': '10:22:38',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:01:17',
#   'nombre': 'Juan Ignacio Medina',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:02:21',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:02:30',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:02:47',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:03:02',
#   'nombre': 'Christian Gabriel Díaz',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:03:14',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:03:57',
#   'nombre': 'Luz Micaela Ponce',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:04:04',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:04:09',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:04:16',
#   'nombre': 'Franco Giacobbe',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:04:17',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:05:22',
#   'nombre': 'Mauro Carrizo',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:06:56',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:07:23',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:09:21',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:10:03',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:13:01',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:15:13',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:15:37',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:17:18',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:17:28',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-10',
#   'hora': '10:44:52',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:05:42',
#   'nombre': 'Santiago Nicolas Ferreyra Appas',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:05:49',
#   'nombre': 'Juan Daniel Morales',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:05:53',
#   'nombre': 'Hector Gabriel Timo',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:05:59',
#   'nombre': 'Thiago Robles',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:05:59',
#   'nombre': 'Luciano Llanos',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:06:02',
#   'nombre': 'Samaniego Esteban Maximiliano',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:06:08',
#   'nombre': 'Ana Sofía Guerrero',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:06:09',
#   'nombre': 'Juan Manuel Agostino Colombres',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:06:22',
#   'nombre': 'Jorge Sebastián Villagra',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:06:52',
#   'nombre': 'Franco Eduardo Drachenberg',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:07:35',
#   'nombre': 'Lisandro Quiroga Castro',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:07:40',
#   'nombre': 'Rodrigo Gonzalez Chavez',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:07:47',
#   'nombre': 'Ignacio Díaz Valdez',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:07:59',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:09:42',
#   'nombre': 'Paulo Marcelo Ledesma',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:10:19',
#   'nombre': 'Jose Maria Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:10:27',
#   'nombre': 'Leonardo Ramirez',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:12:07',
#   'nombre': 'Santiago Esteban Ledesma',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:23:52',
#   'nombre': 'Marcela Noemi Quiroga Quiroga',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '10:39:28',
#   'nombre': 'Tomás Jerez',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '17:13:50',
#   'nombre': 'Lucas Ismael Leon',
#   'comision': 1},
#  {'fecha': '2025-09-11',
#   'hora': '22:17:51',
#   'nombre': 'Alejandro Di Battista',
# ...
#   'nombre': 'Maximiliano Massey',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:20',
#   'nombre': 'Ivam Agustín Herrera Palomino',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:21',
#   'nombre': 'María Matilde Gallo',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:21',
#   'nombre': 'Lourdes Abril Juárez Fernández',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:22',
#   'nombre': 'Juan José Oriz Caballero',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:24',
#   'nombre': 'Martín Gonzalo',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:25',
#   'nombre': 'María Antonela Di Clemente',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:26',
#   'nombre': 'Gabriel Carabajal',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:27',
#   'nombre': 'Facundo Nahuel Trujillo',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:28',
#   'nombre': 'Juan Ignacio Acevedo Costello',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:28',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:28',
#   'nombre': 'Máximo Alberto Collazos Cortez',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:30',
#   'nombre': 'Tomás Gustavo Lagoria Garcia',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:30',
#   'nombre': 'Abril María Agostina Tello',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:30',
#   'nombre': 'Marcelo Ezequiel Duclós',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:30',
#   'nombre': 'Ahumada Aiquen',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:33',
#   'nombre': 'Antonella Soto',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:33',
#   'nombre': 'Sergio Gonzalo Diaz Londero',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:34',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:35',
#   'nombre': 'Leandro Andres Suarez Vece',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:43',
#   'nombre': 'Pablo Isaias Amoedo',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '11:59:47',
#   'nombre': 'Rodrigo Exequiel Ponce',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '12:00:35',
#   'nombre': 'Lucas David Paz Berrondo',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '12:01:02',
#   'nombre': 'Oscar Ignacio Sosa',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '12:04:59',
#   'nombre': 'Martín Javier Gauna Serrano',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '12:05:27',
#   'nombre': 'Matias Gabriel Verón',
#   'comision': 3},
#  {'fecha': '2025-08-26',
#   'hora': '12:34:19',
#   'nombre': 'Gerardo Exequiel Donelli',
#   'comision': 3},
#  {'fecha': '2025-08-27', 'hora': '00:07:52', 'nombre': 'Tú', 'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '10:34:41',
#   'nombre': 'Mariana Aylen Salcedo',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '10:48:04',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:03',
#   'nombre': 'Abril María Agostina Tello',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:09',
#   'nombre': 'Tisera Gaston Lopez',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:10',
#   'nombre': 'Leandro Andres Suarez Vece',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:11',
#   'nombre': 'Juan Segundo Frías Silva',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:12',
#   'nombre': 'María Antonela Di Clemente',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:13',
#   'nombre': 'José Augusto Orellana',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:15',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:16',
#   'nombre': 'Lourdes Abril Juárez Fernández',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:18',
#   'nombre': 'Rodrigo Federico Paz',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:19',
#   'nombre': 'Juan Ignacio Acevedo Costello',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:20',
#   'nombre': 'Alex Daniel Parrado Navarrete',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:21',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:21',
#   'nombre': 'Lucas David Paz Berrondo',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:23',
#   'nombre': 'Maira Acosta',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:25',
#   'nombre': 'Mariano Moya',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:26',
#   'nombre': 'Patricio Agustín Jiménez Paz',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:26',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:28',
#   'nombre': 'Oscar Ignacio Sosa',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:28',
#   'nombre': 'Ahumada Aiquen',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:29',
#   'nombre': 'Antonella Soto',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:29',
#   'nombre': 'Máximo Alberto Collazos Cortez',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:33',
#   'nombre': 'Alfredo Nicolás Romano',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:35',
#   'nombre': 'Tomás Gustavo Lagoria Garcia',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:36',
#   'nombre': 'Maximiliano Massey',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:39',
#   'nombre': 'Facundo Nahuel Trujillo',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:40',
#   'nombre': 'Nahuel Palma Collado',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:07:48',
#   'nombre': 'Ivam Agustín Herrera Palomino',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:08:12',
#   'nombre': 'María Matilde Gallo',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:10:23',
#   'nombre': 'Juan José Oriz Caballero',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:11:24',
#   'nombre': 'Martín Gonzalo',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:15:16',
#   'nombre': 'Sergio Gonzalo Diaz Londero',
#   'comision': 3},
#  {'fecha': '2025-08-27',
#   'hora': '12:16:58',
#   'nombre': 'Rodrigo Exequiel Ponce',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:00:53',
#   'nombre': 'Máximo Alberto Collazos Cortez',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:00:59',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:02',
#   'nombre': 'Rodrigo Federico Paz',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:04',
#   'nombre': 'Mariana Aylen Salcedo',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:04',
#   'nombre': 'Marcelo Ezequiel Duclós',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:05',
#   'nombre': 'Hernán Ignacio Lobo Campero',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:05',
#   'nombre': 'Juan Segundo Frías Silva',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:06',
#   'nombre': 'Juan Ignacio Acevedo Costello',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:07',
#   'nombre': 'Abril María Agostina Tello',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:08',
#   'nombre': 'Nahuel Palma Collado',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:09',
#   'nombre': 'Gabriel Carabajal',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:10',
#   'nombre': 'Tomás Gustavo Lagoria Garcia',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:13',
#   'nombre': 'Alfredo Nicolás Romano',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:13',
#   'nombre': 'Maximiliano Massey',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:16',
#   'nombre': 'Mia de los Angeles Lobo Barrera',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:26',
#   'nombre': 'Oscar Ignacio Sosa',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:29',
#   'nombre': 'Alex Daniel Parrado Navarrete',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:31',
#   'nombre': 'Mia de los Angeles Lobo Barrera',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:34',
#   'nombre': 'Tisera Gaston Lopez',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:37',
#   'nombre': 'Ivam Agustín Herrera Palomino',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:39',
#   'nombre': 'Facundo Nahuel Trujillo',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:01:41',
#   'nombre': 'Lourdes Abril Juárez Fernández',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:02:05',
#   'nombre': 'José Augusto Orellana',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:02:12',
#   'nombre': 'Maira Acosta',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:02:13',
#   'nombre': 'Lucas David Paz Berrondo',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:02:54',
#   'nombre': 'Patricio Agustín Jiménez Paz',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:03:11',
#   'nombre': 'Martín Javier Gauna Serrano',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:03:18',
#   'nombre': 'Matias Gabriel Verón',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:03:43',
#   'nombre': 'Sergio Gonzalo Diaz Londero',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:03:54',
#   'nombre': 'Juan José Oriz Caballero',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:05:26',
#   'nombre': 'Ahumada Aiquen',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:05:56',
#   'nombre': 'Martín Gonzalo',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:07:33',
#   'nombre': 'Antonella Soto',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:08:36',
#   'nombre': 'Pablo Isaias Amoedo',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:24:56',
#   'nombre': 'Rodrigo Exequiel Ponce',
#   'comision': 3},
#  {'fecha': '2025-08-28',
#   'hora': '12:46:42',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:33',
#   'nombre': 'María Matilde Gallo',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:49',
#   'nombre': 'Abril María Agostina Tello',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:56',
#   'nombre': 'Tomás Gustavo Lagoria Garcia',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:57',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:57',
#   'nombre': 'María Antonela Di Clemente',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:58',
#   'nombre': 'Máximo Alberto Collazos Cortez',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:58:59',
#   'nombre': 'Gerardo Exequiel Donelli',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:59:02',
#   'nombre': 'Leandro Andres Suarez Vece',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:59:08',
#   'nombre': 'Ahumada Aiquen',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '11:59:33',
#   'nombre': 'Juan José Oriz Caballero',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:00:42',
#   'nombre': 'Maximiliano Massey',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:01:06',
#   'nombre': 'Juan Ignacio Acevedo Costello',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:01:10',
#   'nombre': 'Lourdes Abril Juárez Fernández',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:02:49',
#   'nombre': 'Nahuel Palma Collado',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:04:19',
#   'nombre': 'Gabriel Carabajal',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:06:18',
#   'nombre': 'Martín Gonzalo',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:07:15',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:17:17',
#   'nombre': 'Oscar Ignacio Sosa',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:20:27',
#   'nombre': 'Maira Acosta',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:21:07',
#   'nombre': 'Antonella Soto',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:29:45',
#   'nombre': 'Tisera Gaston Lopez',
#   'comision': 3},
#  {'fecha': '2025-08-29',
#   'hora': '12:30:11',
#   'nombre': 'Patricio Agustín Jiménez Paz',
#   'comision': 3},
#  {'fecha': '2025-09-02',
#   'hora': '10:21:59',
#   'nombre': 'Alan Godoy',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:02:55',
#   'nombre': 'Máximo Alberto Collazos Cortez',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:02:58',
#   'nombre': 'Nahuel Palma Collado',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:11',
#   'nombre': 'Maximiliano Massey',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:15',
#   'nombre': 'Juan José Oriz Caballero',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:16',
#   'nombre': 'Lourdes Abril Juárez Fernández',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:18',
#   'nombre': 'Abril María Agostina Tello',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:21',
#   'nombre': 'Juan Martín Molina Navarro',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:22',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:25',
#   'nombre': 'Juan Segundo Frías Silva',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:26',
#   'nombre': 'Gerardo Exequiel Donelli',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:26',
#   'nombre': 'José Augusto Orellana',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:27',
#   'nombre': 'Lucas David Paz Berrondo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:28',
#   'nombre': 'María Matilde Gallo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:35',
#   'nombre': 'Ivam Agustín Herrera Palomino',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:38',
#   'nombre': 'María Antonela Di Clemente',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:39',
#   'nombre': 'Lucas David Paz Berrondo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:39',
#   'nombre': 'Antonella Soto',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:40',
#   'nombre': 'Marcelo Ezequiel Duclós',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:03:49',
#   'nombre': 'Alfredo Nicolás Romano',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:04:10',
#   'nombre': 'Oscar Ignacio Sosa',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:04:16',
#   'nombre': 'Facundo Nahuel Trujillo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:04:22',
#   'nombre': 'Sergio Gonzalo Diaz Londero',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:04:24',
#   'nombre': 'Maira Acosta',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:04:50',
#   'nombre': 'Mariano Moya',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:05:01',
#   'nombre': 'Mia de los Angeles Lobo Barrera',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:06:27',
#   'nombre': 'Ahumada Aiquen',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:08:51',
#   'nombre': 'Matias Gabriel Verón',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:09:09',
#   'nombre': 'Santiago Martínez Campero',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:16:38',
#   'nombre': 'Pablo Isaias Amoedo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:29:43',
#   'nombre': 'Mariana Aylen Salcedo',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:39:44',
#   'nombre': 'Martín Javier Gauna Serrano',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:52:13',
#   'nombre': 'Patricio Agustín Jiménez Paz',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '12:55:47',
#   'nombre': 'Rodrigo Exequiel Ponce',
#   'comision': 3},
#  {'fecha': '2025-09-03',
#   'hora': '20:14:43',
#   'nombre': 'Alejandro Di Battista',
#   'comision': 3},
#  ...]
