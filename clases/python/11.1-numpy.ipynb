# %%
import numpy as np

a = np.array([1, 2, 3, 4])     # array unidimensional
b = np.array([[1, 2, 5], [3, 4, 6]]) # array bidimensional

print(a)
print(b)
# Out:
# [1 2 3 4]
# [[1 2 5]
#  [3 4 6]]

# %%
print(a.ndim)  # número de dimensiones → 1
print(b.shape) # forma del array → (2, 2)
print(b.size)  # cantidad total de elementos → 4
print(b.dtype) # tipo de dato → int64 (por ejemplo)
# Out:
# 1
# (2, 3)
# 6
# int64

# %%
np.zeros((2,3))      # matriz 2x3 llena de ceros
np.ones((2,3))       # matriz 2x3 llena de unos
np.arange(0,10,2)    # [0, 2, 4, 6, 8]
np.linspace(0,1,5)   # [0. , 0.25, 0.5 , 0.75, 1. ]
np.eye(3)            # matriz identidad 3x3

print(np.linspace(-3.14,3.14,100))
# Out:
# [-3.14       -3.07656566 -3.01313131 -2.94969697 -2.88626263 -2.82282828
#  -2.75939394 -2.6959596  -2.63252525 -2.56909091 -2.50565657 -2.44222222
#  -2.37878788 -2.31535354 -2.25191919 -2.18848485 -2.12505051 -2.06161616
#  -1.99818182 -1.93474747 -1.87131313 -1.80787879 -1.74444444 -1.6810101
#  -1.61757576 -1.55414141 -1.49070707 -1.42727273 -1.36383838 -1.30040404
#  -1.2369697  -1.17353535 -1.11010101 -1.04666667 -0.98323232 -0.91979798
#  -0.85636364 -0.79292929 -0.72949495 -0.66606061 -0.60262626 -0.53919192
#  -0.47575758 -0.41232323 -0.34888889 -0.28545455 -0.2220202  -0.15858586
#  -0.09515152 -0.03171717  0.03171717  0.09515152  0.15858586  0.2220202
#   0.28545455  0.34888889  0.41232323  0.47575758  0.53919192  0.60262626
#   0.66606061  0.72949495  0.79292929  0.85636364  0.91979798  0.98323232
#   1.04666667  1.11010101  1.17353535  1.2369697   1.30040404  1.36383838
#   1.42727273  1.49070707  1.55414141  1.61757576  1.6810101   1.74444444
# ...

# %%
a = np.array([
        [1,2,3,40],
        [4,5,6,70],
        [7,8,9,100],
        [10,11,12,130]
        ])

# print(a[0, 1])   # elemento fila 0, col 1 → 2
# print(a[1, :])   # segunda fila → [4 5 6]
# print(a[:, 2])   # tercera columna → [3 6 9]
# print(a[0:2:2, 1:3:2]) # submatriz → [[2 3], [5 6]]
# a[0:2, 1:3] = 100
print(a)
# print(a[0:3:2, 0:4:2])
# a[0:3:1, 0:4:3] = 99
# print((a>5))
print( a * (a>5))
# Out:
# [[  1   2   3  40]
#  [  4   5   6  70]
#  [  7   8   9 100]
#  [ 10  11  12 130]]
# [[False False False  True]
#  [False False  True  True]
#  [ True  True  True  True]
#  [ True  True  True  True]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image


img = Image.open("./semaforo.jpg")      # abrir imagen
a = np.array(img)         # convertir a array NumPy
print(a.shape)  # (alto, ancho, 3)
plt.imshow(a)
plt.title("Imagen original")
plt.show()

r = a[50:150,300:,0]
g = a[50:150,300:,1]
b = a[50:150,300:,2]

plt.subplot(3,1,1)
plt.imshow(r, cmap="Reds")
plt.subplot(3,1,2)
plt.imshow(g, cmap="Greens")
plt.subplot(3,1,3)
plt.imshow(b, cmap="Blues")

a[0:100,100:200] = [255,255,50]   # poner rojo en la parte superior
plt.imshow(a)
# Out:
# (306, 612, 3)

# %%
import math

import matplotlib.pyplot as plt
import numpy as np

gamma = np.vectorize(math.gamma)
N = 31
x = np.linspace(0., 10., N)
lambdas = range(1, 9)

ax = plt.figure().add_subplot(projection='3d')

facecolors = plt.colormaps['viridis_r'](np.linspace(0, 1, len(lambdas)))

for i, l in enumerate(lambdas):
    # Note fill_between can take coordinates as length N vectors, or scalars
    ax.fill_between(x, l, l**x * np.exp(-l) / gamma(x + 1),
                    x, l, 0,
                    facecolors=facecolors[i], alpha=.7)

ax.set(xlim=(0, 10), ylim=(1, 9), zlim=(0, 0.35),
       xlabel='x', ylabel=r'$\lambda$', zlabel='probability')

plt.show()
