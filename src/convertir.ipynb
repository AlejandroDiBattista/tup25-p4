# %%
import os
import re
import shutil
import time
from pathlib import Path

from dotenv import load_dotenv
from github import Github

load_dotenv()

github = Github(os.getenv('GITHUB_TOKEN'))
repo = github.get_repo("AlejandroDiBattista/tup25-p4")

def leer(origen: str = "./alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()

            if sline.startswith("##"):
                # Tomar último caracter numérico de la cabecera (p. ej. '## Comisión 1')
                comision = "C" + sline.strip("# \n")[-1]

            if sline.startswith("- "):
                valores = re.split(r"\s{2,}", sline.strip("- \n"))
                if len(valores) == 3:
                    valores.append("c")
                valores.append(comision)
                valores = dict(zip('legajo nombre telefono estado comision'.split(), valores))
                salida.append(valores)

    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md"):
    """ 
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """

    print(f"> Escribiendo {destino}...")
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision[-1]}\n\n")
            archivo.write("```text\n")
            for alumno in alumnos:
                if alumno['comision'] == comision:
                    archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:40}  {alumno['telefono']}  {alumno['estado']}\n")
            archivo.write("```\n")
    return alumnos


def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            # Separar nombre y apellidos
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                # Formato: "Apellido, Nombre"
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                # Si no tiene el formato esperado, usar todo como nombre
                nombres = nombre_completo
                apellidos = ""
            
            # Limpiar el número de teléfono (remover espacios y caracteres especiales)
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            
            # Generar VCard
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {alumno['legajo']} - Comision: P4-{alumno['comision']}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")
    
    print(f"Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen)


def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"../tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro.
    
    Si existe una carpeta con el mismo legajo pero nombre diferente, la renombra.
    Si no existe carpeta, la crea nueva.
    """
    raiz = Path('../tp')  # Usar la ruta correcta hacia tp/
    raiz.mkdir(parents=True, exist_ok=True)  # Asegurar que el directorio tp existe
    
    print(f"> Procesando {len(alumnos)} alumnos en {raiz}...")
    for a in alumnos:
        # Calcular nombre de carpeta destino (sin el prefijo ../tp/)
        destino = raiz / f"{a['legajo']} - {a['nombre']}"
        
        # Buscar carpetas existentes con el mismo legajo
        carpetas_existentes = list(raiz.glob(f"{a['legajo']} -*"))
        print(f"Legajo {a['legajo']} listo en {destino}")

        if carpetas_existentes:
            # Si existe al menos una carpeta con este legajo
            carpeta_actual = carpetas_existentes[0]  # Tomar la primera
            
            if carpeta_actual != destino:
                # Si el nombre es diferente, renombrar
                print(f"  Renombrando: {carpeta_actual} \n             > {destino}")
                try:
                    carpeta_actual.rename(destino)
                except Exception as e:
                    print(f"Error al renombrar {carpeta_actual}: {e}")
                    continue
        else:
            # Si no existe carpeta con este legajo, crearla
            print(f"Creando nueva carpeta: {destino}")
            destino.mkdir(parents=True, exist_ok=True)
        if str(a['legajo']) == '61141':
            print(f"DEBUG: Procesando legajo {a['legajo']} en {destino} (de {carpetas_existentes})")

        # Asegurar que la carpeta existe y escribir/actualizar info.txt

        info_file = destino / "info.txt"
        if not info_file.exists():
            info_content = (
                f"Legajo: {a['legajo']}\n",
                f"Nombre: {a['nombre']}\n",
                f"Teléfono: {a['telefono']}\n",
                f"Comisión: {a['comision']}\n",
            )
            info_file.write_text(info_content, encoding='utf-8')
            print(f"Creado info.txt en: {destino}")

def normalizar_carpetas(origen='alumnos.md'):
    """ Normaliza el archivo y crea las carpetas correspondientes. """
    alumnos = leer()
    print("> Normalizando nombres de carpetas...")
    crear_carpetas(alumnos)
    print("| Proceso normalización de carpetas finalizado.")

normalizar()
alumnos = leer()
print(f"> {len(alumnos)} alumnos leídos.")
# normalizar()
normalizar_carpetas()
# crear_carpetas(leer())
# Out:
# > Leyendo alumnos.md...
# > Escribiendo alumnos.md...
# > Leyendo ./alumnos.md...
# > 82 alumnos leídos.
# > Leyendo ./alumnos.md...
# > Normalizando nombres de carpetas...
# > Procesando 82 alumnos en ../tp...
# Legajo 54911 listo en ../tp/54911 - Jatib, Rodrigo Gabriel
# Legajo 61033 listo en ../tp/61033 - Quiroga, José María
# Legajo 61035 listo en ../tp/61035 - Ledesma, Paulo Marcelo
# Legajo 61046 listo en ../tp/61046 - Ponce, Luz Micaela
# Legajo 61073 listo en ../tp/61073 - González Chavez, Rodrigo
# Legajo 61084 listo en ../tp/61084 - Ramírez, Leonardo
# Legajo 61115 listo en ../tp/61115 - Ledesma, Santiago Esteban
# Legajo 61120 listo en ../tp/61120 - Guerrero, Ana Sofía
# Legajo 61131 listo en ../tp/61131 - Agostino Colombres, Juan Manuel
# Legajo 61167 listo en ../tp/61167 - Giacobbe, Franco
# Legajo 61198 listo en ../tp/61198 - Ferreyra Appas, Santiago Nicolás
# Legajo 61236 listo en ../tp/61236 - Drachenberg, Franco Eduardo
# Legajo 61240 listo en ../tp/61240 - Timo, Héctor Gabriel
# Legajo 61315 listo en ../tp/61315 - Robles, Thiago
# Legajo 61335 listo en ../tp/61335 - León, Lucas Ismael
# Legajo 61337 listo en ../tp/61337 - Díaz, Christian Gabriel
# Legajo 61338 listo en ../tp/61338 - Morales, Juan Daniel
# Legajo 61463 listo en ../tp/61463 - González, Vladimir
# Legajo 61468 listo en ../tp/61468 - Samaniego, Esteban Maximiliano
# Legajo 61472 listo en ../tp/61472 - Díaz, Julieta Camila
# Legajo 61551 listo en ../tp/61551 - Díaz Valdez, Ignacio
# Legajo 61565 listo en ../tp/61565 - Carrizo, Mauro
# Legajo 61725 listo en ../tp/61725 - Villagra, Jorge Sebastián
# Legajo 61805 listo en ../tp/61805 - Jerez, Tomás
# Legajo 61813 listo en ../tp/61813 - Figueroa, Manuel
# Legajo 61911 listo en ../tp/61911 - Llanos, Luciano
# Legajo 61993 listo en ../tp/61993 - Medina, Juan Ignacio
# Legajo 62171 listo en ../tp/62171 - Ballespin, Cristián
#   Renombrando: ../tp/62171 - Ballespin, Cristian
#              > ../tp/62171 - Ballespin, Cristián
# Legajo 62175 listo en ../tp/62175 - Quiroga, Marcela Noemí
# Legajo 62263 listo en ../tp/62263 - Orellana, José Augusto
# Legajo 62318 listo en ../tp/62318 - Quiroga Castro, Lisandro
# Legajo 99001 listo en ../tp/99001 - Branda, César
#   Renombrando: ../tp/99001 - Branda, Cesar
#              > ../tp/99001 - Branda, César
# Legajo 61028 listo en ../tp/61028 - Ponce, Rodrigo Exequíel
#   Renombrando: ../tp/61028 - Ponce, Rodrigo Exequiel
#              > ../tp/61028 - Ponce, Rodrigo Exequíel
# Legajo 61032 listo en ../tp/61032 - Moya, Mariano
# Legajo 61037 listo en ../tp/61037 - Paz, Rodrigo Federico
# Legajo 61059 listo en ../tp/61059 - Palavecino, Fabricio Gastón
# Legajo 61096 listo en ../tp/61096 - Suárez Vece, Leandro Andrés
# Legajo 61113 listo en ../tp/61113 - Oríz Caballero, Juan José
# Legajo 61129 listo en ../tp/61129 - Tello, Abril María Agostina
#   Renombrando: ../tp/61129 - Tello, Abril María Agosti
#              > ../tp/61129 - Tello, Abril María Agostina
# Legajo 61136 listo en ../tp/61136 - Sosa, Oscar Ignacio
# Legajo 61139 listo en ../tp/61139 - Gallo, María Matilde
# Legajo 61141 listo en ../tp/61141 - Di Clemente, María Antonela
# DEBUG: Procesando legajo 61141 en ../tp/61141 - Di Clemente, María Antonela (de [PosixPath('../tp/61141 - Di Clemente, María Antonela')])
# Legajo 61150 listo en ../tp/61150 - Molina Navarro, Juan Martín
# Legajo 61197 listo en ../tp/61197 - Romano, Alfredo Nicolás
# Legajo 61200 listo en ../tp/61200 - Gauna Serrano, Martín Javier
# Legajo 61203 listo en ../tp/61203 - Acevedo Costello, Juan Ignacio
# Legajo 61214 listo en ../tp/61214 - Collazos Cortez, Máximo Alberto
# Legajo 61221 listo en ../tp/61221 - Duclós, Marcelo Ezequiel
# Legajo 61248 listo en ../tp/61248 - Palma Collado, Nahuel
# Legajo 61271 listo en ../tp/61271 - Donelli, Gerardo Exequíel
#   Renombrando: ../tp/61271 - Donelli, Gerardo Exequiel
#              > ../tp/61271 - Donelli, Gerardo Exequíel
# Legajo 61312 listo en ../tp/61312 - Paz Berrondo, Lucas David
# Legajo 61319 listo en ../tp/61319 - Carabajal, José Gabriel
# Legajo 61352 listo en ../tp/61352 - García Moya, José Ignacio
# Legajo 61445 listo en ../tp/61445 - Martínez Campero, Santiago
# Legajo 61450 listo en ../tp/61450 - Jiménez Paz, Patricio Agustín
# Legajo 61473 listo en ../tp/61473 - Lagoria García, Tomás Gustavo
# Legajo 61478 listo en ../tp/61478 - Soto, Antonella
# Legajo 61562 listo en ../tp/61562 - Helguera, Agustina Elizabeth
# Legajo 61572 listo en ../tp/61572 - Parrado Navarrete, Alex Daniel
# Legajo 61579 listo en ../tp/61579 - Gonzalo, Martín
#   Renombrando: ../tp/61579 - Gonzalo, Martí
#              > ../tp/61579 - Gonzalo, Martín
# Legajo 61581 listo en ../tp/61581 - Naim, Federico Paz
# Legajo 61595 listo en ../tp/61595 - González Patti, Valentín
# Legajo 61624 listo en ../tp/61624 - Godoy, Alan
# Legajo 61626 listo en ../tp/61626 - Díaz Londero, Sergio Gonzalo
# Legajo 61627 listo en ../tp/61627 - Juárez Fernández, Lourdes Abril
# Legajo 61667 listo en ../tp/61667 - Acosta, Maira
# Legajo 61676 listo en ../tp/61676 - Massey, Maximiliano
# Legajo 61679 listo en ../tp/61679 - Lobo Barrera, María de los Ángeles
#   Renombrando: ../tp/61679 - Lobo Barrera, Mía de los Ángeles
#              > ../tp/61679 - Lobo Barrera, María de los Ángeles
# Legajo 61719 listo en ../tp/61719 - Amoedo, Pablo Isaías
#   Renombrando: ../tp/61719 - Amoedo, Pablo Isaias
#              > ../tp/61719 - Amoedo, Pablo Isaías
# Legajo 61720 listo en ../tp/61720 - Fernández, Luciano
# Legajo 61730 listo en ../tp/61730 - Díaz, Antonio
# Legajo 61793 listo en ../tp/61793 - Trujillo, Facundo Nahuel
# Legajo 61794 listo en ../tp/61794 - Lobo Campero, Hernán Ignacio
# Legajo 61818 listo en ../tp/61818 - López, Tisera Gastón
#   Renombrando: ../tp/61818 - López, Tisera Gaston
#              > ../tp/61818 - López, Tisera Gastón
# Legajo 61862 listo en ../tp/61862 - Zerda, Thomas
# Legajo 61956 listo en ../tp/61956 - Leglisé, Laureano
#   Renombrando: ../tp/61956 - Leglise, Laureano
#              > ../tp/61956 - Leglisé, Laureano
# Legajo 62053 listo en ../tp/62053 - Herrera Palomino, Iván Agustín
# Legajo 62055 listo en ../tp/62055 - Aumada, Aiquen Osvaldo
# Legajo 62093 listo en ../tp/62093 - Frías Silva, Juan Segundo
# Legajo 62172 listo en ../tp/62172 - Salcedo, Mariana Aylén
#   Renombrando: ../tp/62172 - Salcedo, Mariana Aylen
#              > ../tp/62172 - Salcedo, Mariana Aylén
# Legajo 62263 listo en ../tp/62263 - Orellana, José Augusto
# Legajo 62555 listo en ../tp/62555 - Verón, Matías Gabriel
# | Proceso normalización de carpetas finalizado.

# %%
def copiar_tp(tp=1, alumnos=None):
    """ Copia todos los archivos y subcarpetas de enunciados/tp{tp}
        a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"../enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        print(f"\n==> Copiando en {destino_base}")

        for origen in origen_base.rglob('*'):
            rel = origen.relative_to(origen_base)
            destino = destino_base / rel

            destino.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(origen, destino)
            print(f"Copiado: {origen} -> {destino}")


# alumnos = leer()
# crear_carpetas(alumnos)
# copiar_tp(2, alumnos)
# Out:
# > Leyendo alumnos.md...
#
# ==> Copiando en ../tp/54911 - Jatib, Rodrigo Gabriel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/54911 - Jatib, Rodrigo Gabriel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61033 - Quiroga, Jose Maria/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61033 - Quiroga, Jose Maria/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61033 - Quiroga, Jose Maria/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61033 - Quiroga, Jose Maria/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61033 - Quiroga, Jose Maria/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61033 - Quiroga, Jose Maria/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61033 - Quiroga, Jose Maria/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61035 - Ledesma, Paulo Marcelo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61035 - Ledesma, Paulo Marcelo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61046 - Ponce, Luz Micaela/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61046 - Ponce, Luz Micaela/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61046 - Ponce, Luz Micaela/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61046 - Ponce, Luz Micaela/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61046 - Ponce, Luz Micaela/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61046 - Ponce, Luz Micaela/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61046 - Ponce, Luz Micaela/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61073 - Gonzalez Chavez, Rodrigo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61084 - Ramirez, Leonardo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61084 - Ramirez, Leonardo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61084 - Ramirez, Leonardo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61084 - Ramirez, Leonardo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61084 - Ramirez, Leonardo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61084 - Ramirez, Leonardo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61084 - Ramirez, Leonardo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61115 - Ledesma, Santiago Esteban/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61115 - Ledesma, Santiago Esteban/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61120 - Guerrero, Ana Sofía/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61120 - Guerrero, Ana Sofía/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61120 - Guerrero, Ana Sofía/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61120 - Guerrero, Ana Sofía/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61120 - Guerrero, Ana Sofía/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61120 - Guerrero, Ana Sofía/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61120 - Guerrero, Ana Sofía/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61131 - Agostino Colombres, Juan Manuel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61131 - Agostino Colombres, Juan Manuel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61167 - Giacobbe, Franco/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61167 - Giacobbe, Franco/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61167 - Giacobbe, Franco/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61167 - Giacobbe, Franco/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61167 - Giacobbe, Franco/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61167 - Giacobbe, Franco/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61167 - Giacobbe, Franco/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61198 - Ferreyra Appas, Santiago Nicolas/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61236 - Drachenberg, Franco Eduardo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61236 - Drachenberg, Franco Eduardo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61240 - Timo, Hector Gabriel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61240 - Timo, Hector Gabriel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61240 - Timo, Hector Gabriel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61240 - Timo, Hector Gabriel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61240 - Timo, Hector Gabriel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61240 - Timo, Hector Gabriel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61240 - Timo, Hector Gabriel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61315 - Robles,Thiago/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61315 - Robles,Thiago/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61315 - Robles,Thiago/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61315 - Robles,Thiago/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61315 - Robles,Thiago/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61315 - Robles,Thiago/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61315 - Robles,Thiago/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61335 - Leon, Lucas Ismael/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61335 - Leon, Lucas Ismael/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61335 - Leon, Lucas Ismael/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61335 - Leon, Lucas Ismael/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61335 - Leon, Lucas Ismael/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61335 - Leon, Lucas Ismael/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61335 - Leon, Lucas Ismael/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61337 - Díaz, Christian Gabriel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61337 - Díaz, Christian Gabriel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61337 - Díaz, Christian Gabriel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61337 - Díaz, Christian Gabriel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61337 - Díaz, Christian Gabriel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61337 - Díaz, Christian Gabriel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61337 - Díaz, Christian Gabriel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61338 - Morales, Juan Daniel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61338 - Morales, Juan Daniel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61338 - Morales, Juan Daniel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61338 - Morales, Juan Daniel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61338 - Morales, Juan Daniel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61338 - Morales, Juan Daniel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61338 - Morales, Juan Daniel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61463 - Gonzalez, Vladimir/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61463 - Gonzalez, Vladimir/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61463 - Gonzalez, Vladimir/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61463 - Gonzalez, Vladimir/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61463 - Gonzalez, Vladimir/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61463 - Gonzalez, Vladimir/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61463 - Gonzalez, Vladimir/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61468 - Samaniego Esteban Maximiliano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61468 - Samaniego Esteban Maximiliano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61472 - Diaz, Julieta Camila/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61472 - Diaz, Julieta Camila/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61472 - Diaz, Julieta Camila/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61472 - Diaz, Julieta Camila/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61472 - Diaz, Julieta Camila/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61472 - Diaz, Julieta Camila/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61472 - Diaz, Julieta Camila/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61551 - Diaz Valdez, Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61551 - Diaz Valdez, Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61565 - Carrizo, Mauro/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61565 - Carrizo, Mauro/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61565 - Carrizo, Mauro/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61565 - Carrizo, Mauro/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61565 - Carrizo, Mauro/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61565 - Carrizo, Mauro/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61565 - Carrizo, Mauro/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61725 - Villagra, Jorge Sebastián/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61725 - Villagra, Jorge Sebastián/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61805 - Jerez, Tomás/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61805 - Jerez, Tomás/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61805 - Jerez, Tomás/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61805 - Jerez, Tomás/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61805 - Jerez, Tomás/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61805 - Jerez, Tomás/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61805 - Jerez, Tomás/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61813 - Figueroa, Manuel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61813 - Figueroa, Manuel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61813 - Figueroa, Manuel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61813 - Figueroa, Manuel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61813 - Figueroa, Manuel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61813 - Figueroa, Manuel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61813 - Figueroa, Manuel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61911 - Llanos, Luciano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61911 - Llanos, Luciano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61911 - Llanos, Luciano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61911 - Llanos, Luciano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61911 - Llanos, Luciano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61911 - Llanos, Luciano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61911 - Llanos, Luciano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61993 - Medina, Juan Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61993 - Medina, Juan Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61993 - Medina, Juan Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61993 - Medina, Juan Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61993 - Medina, Juan Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61993 - Medina, Juan Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61993 - Medina, Juan Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62171 - Ballespin, Cristian/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62171 - Ballespin, Cristian/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62171 - Ballespin, Cristian/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62171 - Ballespin, Cristian/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62171 - Ballespin, Cristian/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62171 - Ballespin, Cristian/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62171 - Ballespin, Cristian/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62175 - Quiroga, Marcela Noemi Quiroga/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62263 - Orellana, José Augusto/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62263 - Orellana, José Augusto/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62263 - Orellana, José Augusto/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62263 - Orellana, José Augusto/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62318 - Quiroga Castro, Lisandro/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62318 - Quiroga Castro, Lisandro/tp2/ejercicio.html
#
# ==> Copiando en ../tp/99001 - Branda, Cesar/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/99001 - Branda, Cesar/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/99001 - Branda, Cesar/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/99001 - Branda, Cesar/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/99001 - Branda, Cesar/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/99001 - Branda, Cesar/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/99001 - Branda, Cesar/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61028 - Ponce, Rodrigo Exequiel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61028 - Ponce, Rodrigo Exequiel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61032 - Moya, Mariano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61032 - Moya, Mariano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61032 - Moya, Mariano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61032 - Moya, Mariano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61032 - Moya, Mariano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61032 - Moya, Mariano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61032 - Moya, Mariano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61037 - Paz, Rodrigo Federico/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61037 - Paz, Rodrigo Federico/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61037 - Paz, Rodrigo Federico/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61037 - Paz, Rodrigo Federico/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61037 - Paz, Rodrigo Federico/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61037 - Paz, Rodrigo Federico/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61037 - Paz, Rodrigo Federico/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61059 - Palavecino, Fabricio Gaston/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61059 - Palavecino, Fabricio Gaston/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61096 - Suárez Vece, Leandro Andrés/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61096 - Suárez Vece, Leandro Andrés/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61113 - Oríz Caballero, Juan José/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61113 - Oríz Caballero, Juan José/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61113 - Oríz Caballero, Juan José/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61113 - Oríz Caballero, Juan José/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61113 - Oríz Caballero, Juan José/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61113 - Oríz Caballero, Juan José/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61113 - Oríz Caballero, Juan José/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61129 - Tello, Abril María Agosti/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61129 - Tello, Abril María Agosti/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61129 - Tello, Abril María Agosti/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61129 - Tello, Abril María Agosti/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61129 - Tello, Abril María Agosti/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61129 - Tello, Abril María Agosti/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61129 - Tello, Abril María Agosti/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61136 - Sosa, Oscar Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61136 - Sosa, Oscar Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61139 - Gallo, María Matilde/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61139 - Gallo, María Matilde/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61139 - Gallo, María Matilde/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61139 - Gallo, María Matilde/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61141 - Di Clemente, Maria Antonela/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61150 - Molina Navarro, Juan Martin/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61197 - Romano, Alfredo Nicolás/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61200 - Gauna Serrano, Martin Javier/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61221 - Duclós, Marcelo Ezequiel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61248 - Palma Collado, Nahuel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61248 - Palma Collado, Nahuel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61248 - Palma Collado, Nahuel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61248 - Palma Collado, Nahuel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61271 - Donelli, Gerardo Exequiel/tp2
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61139 - Gallo, María Matilde/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61139 - Gallo, María Matilde/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61139 - Gallo, María Matilde/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61141 - Di Clemente, Maria Antonela/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61141 - Di Clemente, Maria Antonela/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61150 - Molina Navarro, Juan Martin/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61150 - Molina Navarro, Juan Martin/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61197 - Romano, Alfredo Nicolás/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61197 - Romano, Alfredo Nicolás/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61200 - Gauna Serrano, Martin Javier/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61200 - Gauna Serrano, Martin Javier/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61203 - Acevedo Costello, Juan Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61214 - Collazos Cortez, Maximo Alberto/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61221 - Duclós, Marcelo Ezequiel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61221 - Duclós, Marcelo Ezequiel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61248 - Palma Collado, Nahuel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61248 - Palma Collado, Nahuel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61248 - Palma Collado, Nahuel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61248 - Palma Collado, Nahuel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61248 - Palma Collado, Nahuel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61271 - Donelli, Gerardo Exequiel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61271 - Donelli, Gerardo Exequiel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61312 - Paz Berrondo, Lucas David/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61312 - Paz Berrondo, Lucas David/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61319 - Carabajal, José Gabriel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61319 - Carabajal, José Gabriel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61319 - Carabajal, José Gabriel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61319 - Carabajal, José Gabriel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61319 - Carabajal, José Gabriel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61319 - Carabajal, José Gabriel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61319 - Carabajal, José Gabriel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61352 - García Moya, José Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61352 - García Moya, José Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61352 - García Moya, José Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61352 - García Moya, José Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61352 - García Moya, José Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61352 - García Moya, José Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61352 - García Moya, José Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61445 - Martínez Campero, Santiago/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61445 - Martínez Campero, Santiago/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61445 - Martínez Campero, Santiago/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61445 - Martínez Campero, Santiago/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61445 - Martínez Campero, Santiago/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61445 - Martínez Campero, Santiago/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61445 - Martínez Campero, Santiago/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61450 - Jimenez Paz, Patricio Agustín/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61473 - Lagoria Garcia, Tomás Gustavo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61478 - Soto, Antonella/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61478 - Soto, Antonella/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61478 - Soto, Antonella/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61478 - Soto, Antonella/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61478 - Soto, Antonella/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61478 - Soto, Antonella/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61478 - Soto, Antonella/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61562 - Helguera, Agustina Elizabeth/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61562 - Helguera, Agustina Elizabeth/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61572 - Parrado Navarrete, Alex Daniel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61579 - Gonzalo, Marti/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61579 - Gonzalo, Marti/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61579 - Gonzalo, Marti/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61579 - Gonzalo, Marti/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61579 - Gonzalo, Marti/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61579 - Gonzalo, Marti/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61579 - Gonzalo, Marti/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61581 - Naim, Federico Paz/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61581 - Naim, Federico Paz/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61581 - Naim, Federico Paz/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61581 - Naim, Federico Paz/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61581 - Naim, Federico Paz/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61581 - Naim, Federico Paz/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61581 - Naim, Federico Paz/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61595 - Gonzalez Patti, Valentin/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61595 - Gonzalez Patti, Valentin/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61624 - Godoy, Alan/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61624 - Godoy, Alan/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61624 - Godoy, Alan/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61624 - Godoy, Alan/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61624 - Godoy, Alan/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61624 - Godoy, Alan/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61624 - Godoy, Alan/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61626 - Diaz Londero, Sergio Gonzalo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61627 - Juarez Fernandez, Lourdes Abril/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61667 - Acosta, Maira/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61667 - Acosta, Maira/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61667 - Acosta, Maira/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61667 - Acosta, Maira/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61667 - Acosta, Maira/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61667 - Acosta, Maira/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61667 - Acosta, Maira/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61676 - Massey, Maximiliano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61676 - Massey, Maximiliano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61676 - Massey, Maximiliano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61676 - Massey, Maximiliano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61676 - Massey, Maximiliano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61676 - Massey, Maximiliano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61676 - Massey, Maximiliano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61679 - Lobo Barrera, Mia de los Angeles/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61719 - Amoedo, Pablo Isaias/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61719 - Amoedo, Pablo Isaias/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61720 - Fernandez, Luciano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61720 - Fernandez, Luciano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61720 - Fernandez, Luciano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61720 - Fernandez, Luciano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61720 - Fernandez, Luciano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61720 - Fernandez, Luciano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61720 - Fernandez, Luciano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61730 - Diaz, Antonio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61730 - Diaz, Antonio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61730 - Diaz, Antonio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61730 - Diaz, Antonio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61730 - Diaz, Antonio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61730 - Diaz, Antonio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61730 - Diaz, Antonio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61793 - Trujillo, Facundo Nahuel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61793 - Trujillo, Facundo Nahuel/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61794 - Lobo Campero, Hernán Ignacio/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61818 - Lopez, Tisera Gaston/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61818 - Lopez, Tisera Gaston/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61818 - Lopez, Tisera Gaston/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61818 - Lopez, Tisera Gaston/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61818 - Lopez, Tisera Gaston/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61818 - Lopez, Tisera Gaston/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61818 - Lopez, Tisera Gaston/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61862 - Zerda, Thomas/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61862 - Zerda, Thomas/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61862 - Zerda, Thomas/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61862 - Zerda, Thomas/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61862 - Zerda, Thomas/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61862 - Zerda, Thomas/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61862 - Zerda, Thomas/tp2/ejercicio.html
#
# ==> Copiando en ../tp/61956 - Leglise, Laureano/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/61956 - Leglise, Laureano/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/61956 - Leglise, Laureano/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/61956 - Leglise, Laureano/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/61956 - Leglise, Laureano/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/61956 - Leglise, Laureano/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/61956 - Leglise, Laureano/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62053 - Herrera Palomino, Ivan Agustín/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62055 - Aumada, Aiquen Osvaldo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62055 - Aumada, Aiquen Osvaldo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62093 - Frias Silva, Juan Segundo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62093 - Frias Silva, Juan Segundo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62172 - Mariana Aylen Salcedo/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62172 - Mariana Aylen Salcedo/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62172 - Mariana Aylen Salcedo/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62172 - Mariana Aylen Salcedo/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62172 - Mariana Aylen Salcedo/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62172 - Mariana Aylen Salcedo/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62172 - Mariana Aylen Salcedo/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62263 - Orellana, José Augusto/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62263 - Orellana, José Augusto/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62263 - Orellana, José Augusto/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62263 - Orellana, José Augusto/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62263 - Orellana, José Augusto/tp2/ejercicio.html
#
# ==> Copiando en ../tp/62555 - Verón, Matias Gabriel/tp2
# Copiado: ../enunciados/tp2/enunciado.md -> ../tp/62555 - Verón, Matias Gabriel/tp2/enunciado.md
# Copiado: ../enunciados/tp2/ejercicio.css -> ../tp/62555 - Verón, Matias Gabriel/tp2/ejercicio.css
# Copiado: ../enunciados/tp2/agenda1.png -> ../tp/62555 - Verón, Matias Gabriel/tp2/agenda1.png
# Copiado: ../enunciados/tp2/agenda2.png -> ../tp/62555 - Verón, Matias Gabriel/tp2/agenda2.png
# Copiado: ../enunciados/tp2/ejercicio.js -> ../tp/62555 - Verón, Matias Gabriel/tp2/ejercicio.js
# Copiado: ../enunciados/tp2/ejercicio.html -> ../tp/62555 - Verón, Matias Gabriel/tp2/ejercicio.html

# %%
# Ejemplo de uso de la función convertir_vcard
alumnos = leer('alumnos.md')
print(f"Se encontraron {len(alumnos)} alumnos")

# Generar archivo VCard con todos los alumnos
contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

print("Archivos VCard generados exitosamente!")
print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")
# Out:
# > Leyendo alumnos.md...
# Se encontraron 82 alumnos
# > Generando archivo VCard: alumnos.vcf...
# Archivo generado con 82 contactos.
# Archivos VCard generados exitosamente!
# Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.

# %%
# Gestion de repositorio y Pull Requests

def normalizar_titulo_pr(titulo, tp, alumnos):
    if match:= re.search(r'(\d{5})', titulo):
        legajo = match.group(1)
        nombre_alumno = next((a['nombre'] for a in alumnos if a['legajo'] == legajo), "Desconocido")
        return f"TP{tp} - {legajo} - {nombre_alumno}"
    else:
        return titulo

def normalizar_pr(tp=2, estado='open', alumnos=None, min=0, max=9999):
    open_pulls = repo.get_pulls(state=estado, sort='created', base='main')
    print(f"> Pull Requests pendientes:")
    for pr in open_pulls:
        if pr.number < min: continue
        if pr.number > max: continue
        pr = repo.get_pull(pr.number)  # Refrescar datos del PR
        nuevo = normalizar_titulo_pr(pr.title, tp, alumnos)
        if pr.title != nuevo:
            print(f"+ #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}{"*" if pr.title != nuevo else ""}")
            print(f"    >>: {pr.title}")
            pr.edit(title=nuevo)
        else:
            print(f"- #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}")
    print(".")


def merge_prs_sin_conflictos():
    open_pulls = repo.get_pulls(state='open', sort='created', base='main')
    print("> Intentando merge de PRs sin conflictos:")
    for pr in open_pulls:
        pr = repo.get_pull(pr.number)  # Refrescar datos
        # Esperar hasta que mergeable no sea None
        intentos = 0
        max_intentos = 12  # Máximo 12 * 5 = 60 segundos
        while pr.mergeable is None and intentos < max_intentos:
            print(f"     Esperando mergeability para PR #{pr.number}... ({intentos+1}/{max_intentos})")
            time.sleep(5)
            pr = repo.get_pull(pr.number)  # Refrescar
            intentos += 1

        if pr.mergeable is True:  # Solo si puede ser merged
            try:
                pr.merge()
                print(f"- ✅ PR #{pr.number} merged: {pr.title}")
            except Exception as e:
                print(f"- ❌ Error al mergear PR #{pr.number}: {e}")
        elif pr.mergeable is False:
            print(f"- 👁️ PR #{pr.number} tiene conflictos: {pr.title}")
        else:
            print(f"- ⏳ Tiempo agotado para PR #{pr.number}: {pr.title}")
    print(". fin")

# Funciones
# 1. normalizar_pr -> renombra los PRs abiertos con formato estandar
# 2. merge_prs_sin_conflictos -> intenta mergear los PRs sin conflictos

alumnos = leer()
# normalizar_pr(tp=2, estado='open', alumnos=alumnos, min=65)
merge_prs_sin_conflictos()
# Out:
# > Leyendo alumnos.md...
# > Intentando merge de PRs sin conflictos:
# - 👁️ PR #114 tiene conflictos: TP2 - 61565 - Carrizo, Mauro
#      Esperando mergeability para PR #117... (1/12)
# - 👁️ PR #117 tiene conflictos: TP2 - 62175 - Quiroga, Marcela Noemi Quiroga
# . fin
