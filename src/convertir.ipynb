# %%
import os
import re
import shutil
import time
from pathlib import Path

from dotenv import load_dotenv
from github import Github

load_dotenv()

github = Github(os.getenv('GITHUB_TOKEN'))
repo = github.get_repo("AlejandroDiBattista/tup25-p4")

def leer(origen: str = "./alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()

            if sline.startswith("##"):
                # Tomar último caracter numérico de la cabecera (p. ej. '## Comisión 1')
                comision = "C" + sline.strip("# \n")[-1]

            if sline.startswith("- "):
                valores = re.split(r"\s{2,}", sline.strip("- \n"))
                if len(valores) == 3:
                    valores.append("c")
                valores.append(comision)
                valores = dict(zip('legajo nombre telefono estado comision'.split(), valores))
                salida.append(valores)

    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md"):
    """ 
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """

    print(f"> Escribiendo {destino}...")
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision[-1]}\n\n")
            archivo.write("```text\n")
            for alumno in alumnos:
                if not "github" in alumno: alumno["github"] = "-"
                if alumno['comision'] == comision:
                    archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:40}  {alumno['telefono']}  {alumno['estado']} @{alumno['github']}\n")
            archivo.write("```\n")
    return alumnos


def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                nombres = nombre_completo
                apellidos = ""
            
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {alumno['legajo']} - Comision: P4-{alumno['comision']}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")

    print(f"| Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen)


def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"../tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro.
    
    Si existe una carpeta con el mismo legajo pero nombre diferente, la renombra.
    Si no existe carpeta, la crea nueva.
    """
    raiz = Path('../tp')  # Usar la ruta correcta hacia tp/
    raiz.mkdir(parents=True, exist_ok=True)  # Asegurar que el directorio tp existe
    
    print(f"> Procesando {len(alumnos)} alumnos en {raiz}...")
    for a in alumnos:
        # Calcular nombre de carpeta destino (sin el prefijo ../tp/)
        destino = raiz / f"{a['legajo']} - {a['nombre']}"
        
        # Buscar carpetas existentes con el mismo legajo
        carpetas_existentes = list(raiz.glob(f"{a['legajo']} -*"))
        print(f"Legajo {a['legajo']} listo en {destino}")

        if carpetas_existentes:
            # Si existe al menos una carpeta con este legajo
            carpeta_actual = carpetas_existentes[0]  # Tomar la primera
            
            if carpeta_actual != destino:
                # Si el nombre es diferente, renombrar
                print(f"  Renombrando: {carpeta_actual} \n             > {destino}")
                try:
                    carpeta_actual.rename(destino)
                except Exception as e:
                    print(f"Error al renombrar {carpeta_actual}: {e}")
                    continue
        else:
            # Si no existe carpeta con este legajo, crearla
            print(f"Creando nueva carpeta: {destino}")
            destino.mkdir(parents=True, exist_ok=True)

        # Asegurar que la carpeta existe y escribir/actualizar info.txt
        info_file = destino / "info.txt"
        if not info_file.exists():
            info_content = (
                f"Legajo: {a['legajo']}\n",
                f"Nombre: {a['nombre']}\n",
                f"Teléfono: {a['telefono']}\n",
                f"Comisión: {a['comision']}\n",
            )
            info_file.write_text(info_content, encoding='utf-8')
            print(f"Creado info.txt en: {destino}")


def normalizar_carpetas():
    """ Normaliza el archivo y crea las carpetas correspondientes. """
    alumnos = leer()
    print("> Normalizando nombres de carpetas...")
    crear_carpetas(alumnos)
    print("| Proceso normalización de carpetas finalizado.")

# alumnos = leer()
# normalizar()
# normalizar_carpetas()

# crear_carpetas(leer())

# %%
def copiar_tp(tp=1, alumnos=None):
    """ Copia todos los archivos y subcarpetas de enunciados/tp{tp}
        a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"../enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        # print(f"\n==> Copiando en {destino_base}")

        for origen in origen_base.rglob('*'):
            rel = origen.relative_to(origen_base)
            destino = destino_base / rel

            destino.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(origen, destino)
            # print(f"Copiado: {origen} -> {destino}")


# alumnos = leer()
# crear_carpetas(alumnos)
# copiar_tp(2, alumnos)

# %%
# Ejemplo de uso de la función convertir_vcard
alumnos = leer('alumnos.md')
print(f"Se encontraron {len(alumnos)} alumnos")

# Generar archivo VCard con todos los alumnos
contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

print("Archivos VCard generados exitosamente!")
print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")
# Out:
# > Leyendo alumnos.md...
# Se encontraron 82 alumnos
# > Generando archivo VCard: alumnos.vcf...
# | Archivo generado con 82 contactos.
# Archivos VCard generados exitosamente!
# Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.

# %%
# Gestion de repositorio y Pull Requests

def normalizar_titulo(titulo, tp, alumnos):
    if match:= re.search(r'(\d{5})', titulo):
        legajo = match.group(1)
        nombre_alumno = next((a['nombre'] for a in alumnos if a['legajo'] == legajo), "Desconocido")
        return f"TP{tp} - {legajo} - {nombre_alumno}"
    else:
        return titulo

def cargar_github_user(alumnos=None):
    prs = repo.get_pulls(state='closed', sort='created', base='main')

    print(f"> Cargando usuarios de GitHub en {len(alumnos)} alumnos...")
    for pr in prs:
        print(f"PR #{pr.number}: {pr.title} (por {pr.user.login})")
        legajo = re.search(r'(\d{5})', pr.title)
        if legajo:
            alumno = next((x for x in alumnos if x['legajo'] == legajo.group(1)), None)
            if alumno:
                alumno["github"] = pr.user.login
    return alumnos


def normalizar_titulo_pr(tp=2, estado='open', alumnos=None, min=0, max=9999):
    print(f"> Pull Requests pendientes:")

    open_pulls = repo.get_pulls(state=estado, sort='created', base='main')
    for pr in open_pulls:
        if not (min <= pr.number <= max): continue

        pr = repo.get_pull(pr.number)  # Refrescar datos del PR
        nuevo = normalizar_titulo(pr.title, tp, alumnos)
        if pr.title != nuevo:
            print(f"+ #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}{"*" if pr.title != nuevo else ""}")
            print(f"    >>: {pr.title}")
            pr.edit(title=nuevo)
        else:
            print(f"- #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state}")
    print("| fin")


def aceptar_prs_sin_conflictos():
    open_pulls = repo.get_pulls(state='open', sort='created', base='main')
    print("> Intentando merge de PRs sin conflictos:")
    for pr in open_pulls:
        pr = repo.get_pull(pr.number)       # Refrescar datos
        if pr.mergeable is None:
            time.sleep(5)
            pr = repo.get_pull(pr.number)   # Refrescar
        if pr.mergeable:
            try:
                pr.merge()
                print(f"- ✅ PR #{pr.number} mergeado: {pr.title}")
            except Exception as e:
                print(f"- ❌ Error al mergear PR #{pr.number}: {e}")
        elif pr.mergeable is False:
            print(f"- 👁️ PR #{pr.number} tiene conflictos: {pr.title}")
        else:
            print(f"- ⏳ Tiempo agotado para PR #{pr.number}: {pr.title}")
    print("| fin")

# Funciones
# 1. normalizar_pr -> renombra los PRs abiertos con formato estandar
# 2. merge_prs_sin_conflictos -> intenta mergear los PRs sin conflictos

alumnos = leer()
# normalizar_titulo_pr(tp=2, estado='open', alumnos=alumnos, min=65)
print(cargar_github_user(alumnos))
escribir(alumnos)
# merge_prs_sin_conflictos()
# Out:
# > Leyendo ./alumnos.md...
# > Cargando usuarios de GitHub en 82 alumnos...
# PR #1: TP1 - 61572 - Parrado Navarrete, Alex Daniel (por AlexDaniel28)
# PR #2: TP1 - 61131 - Agostino Colombres, Juan Manuel (por JuanmaAgostino)
# PR #3: TP1 - 61627 - Juarez Fernandez, Lourdes Abril (por LourdesFernandez1)
# PR #4: TP1 - 61315 - Robles, Thiago (por T1T0Dev)
# PR #5: TP1 - 61315 - Robles, Thiago (por T1T0Dev)
# PR #6: TP1 - 61911 - Llanos, Luciano (por LucianoLlanos)
# PR #7: TP1 - 61221 - Duclós, Marcelo Ezequiel (por EzeDuclos)
# PR #8: TP1 - 61579 - Gonzalo, Marti (por Lived18)
# PR #9: TP1 - 61312 - Paz Berrondo, Lucas David (por Lucasdxvid)
# PR #10: TP1 - 61033 - Quiroga, Jose Maria (por jose-qui)
# PR #11: TP1 - 62555 - Verón, Matias Gabriel (por MatiasVeron12503)
# PR #12: TP1 - 61096 - Suárez Vece, Leandro Andrés (por leandroVece)
# PR #13: TP1 - 61032 - Moya, Mariano (por mariano-moya)
# PR #14: TP1 - 61271 - Donelli, Gerardo Exequiel (por GerardoExe)
# PR #15: TP1 - 61719 - Amoedo, Pablo Isaias (por Kryfter)
# PR #16: TP1 - 62172 - Mariana Aylen Salcedo (por marianasalcedo22)
# PR #17: TP1 - 61676 - Massey, Maximiliano (por EPILONgaga)
# PR #18: TP1 - 61319 - Carabajal, José Gabriel (por 7GabrielC)
# PR #19: TP1 - 61139 - Gallo, María Matilde (por matildegallom)
# PR #20: TP1 - 61037 - Paz, Rodrigo Federico (por Rodrigopz52)
# PR #21: TP1 - 61445 - Martínez Campero, Santiago (por SantiCampero)
# PR #22: TP1 - 61046 - Ponce, Luz Micaela (por Mica8p)
# PR #23: TP1 - 61335 - Leon, Lucas Ismael (por LuquitasLeon)
# PR #24: TP1 - 61478 - Soto, Antonella (por anto210)
# PR #25: TP1 - 61200 - Gauna Serrano, Martin Javier (por MartinGS8)
# PR #26: TP1 - 61626 - Diaz Londero, Sergio Gonzalo (por Gonzalo-diazz)
# PR #27: TP1 - 61240 - Timo, Hector Gabriel (por GabrielTimo006)
# PR #28: TP1 - 61167 - Giacobbe, Franco (por frandg47)
# PR #29: TP1 - 61468 - Samaniego, Esteban Maximiliano (por MaxiSama12)
# PR #31: TP1 - 61035 - Ledesma, Paulo Marcelo (por pauloled)
# PR #33: TP1 - 61725 - Villagra, Jorge Sebastián (por JorgeVillagraa)
# PR #34: TP1 - 61450 - Jimenez Paz, Patricio Agustín (por patricio-jp)
# PR #35: TP1 - 61794 - Lobo Campero, Hernán Ignacio (por lobohhernan)
# PR #36: TP1 - 61793 - Trujillo, Facundo Nahuel (por FacundoTrujillo)
# PR #37: TP1 - 62175 - Quiroga, Marcela Noemi Quiroga (por Marce-Quiroga)
# PR #38: TP1 - 61473 - Lagoria Garcia, Tomás Gustavo (por tomaslago27)
# PR #39: TP1 - 61565 - Carrizo, Mauro (por DarkoDarkShadow)
# PR #40: TP1 - 61468 - Samaniego, Esteban Maximiliano (por MaxiSama12)
# PR #41: TP1 - 54911 - Jatib, Rodrigo Gabriel (por RodrigoJatib)
# PR #42: TP1 - 61667 - Acosta, Maira (por maira-acostaa)
# PR #43: TP1 - 62055 - Aumada, Aiquen Osvaldo (por aiquen7)
# PR #44: TP1 - 62053 - Herrera Palomino, Ivan Agustín (por ivanagustinherrera)
# PR #45: TP1 - 61338 - Morales, Juan Daniel (por JuanMo17)
# PR #46: TP1 - 61115 - Ledesma, Santiago Esteban (por santled)
# PR #47: TP1 - 61073 - Gonzalez Chavez, Rodrigo (por rodrigogc21)
# PR #48: TP1 - 61028 - Ponce, Rodrigo Exequiel (por rodrikapo12)
# PR #49: TP1 - 61129 - Tello, Abril María Agosti (por abriltello)
# PR #50: TP1 - 61236 - Drachenberg, Franco Eduardo (por FDrach)
# PR #51: TP1 - 61805 - Jerez, Tomás (por ElTommmy)
# PR #52: TP1 - 61136 - Sosa, Oscar Ignacio (por Oscar40997)
# PR #53: TP1 - 61120 - Guerrero, Ana Sofía (por AnaSofi03)
# PR #54: TP1 - 61113 - Oríz Caballero, Juan José (por JuanchoCab)
# PR #55: TP1 - 61150 - Molina Navarro, Juan Martin (por JuanMolinaNavarro)
# PR #56: TP1 - 61198 - Ferreyra Appas, Santiago Nicolas (por Ercutt)
# PR #57: TP1 - 61472 - Diaz, Julieta Camila (por juliidiiaz04)
# PR #58: TP1 - 62263 - Orellana, José Augusto (por Jaodem)
# PR #59: TP1 - 61248 - Palma Collado, Nahuel (por Nahu333)
# PR #60: TP1 - 61197 - Romano, Alfredo Nicolás (por NicoRomano904)
# PR #61: TP1 - 61551 - Diaz Valdez, Ignacio (por IgnacioDiazV)
# PR #62: TP1 - 62318 - Quiroga Castro, Lisandro (por Lisandro-18)
# PR #63: TP1 - 61818 - Lopez, Tisera Gaston (por gastonlopezt)
# PR #64: TP1 - 61141 - Di Clemente, Maria Antonela (por antodiclemente)
# PR #65: TP2 - 62093 - Frias Silva, Juan Segundo (por juansefriass)
# PR #66: TP2 - 61572 - Parrado Navarrete, Alex Daniel (por AlexDaniel28)
# PR #67: TP2 - 61200 - Gauna Serrano, Martin Javier (por MartinGS8)
# PR #68: TP2 - 61579 - Gonzalo, Marti (por Lived18)
# PR #69: TP2 - 61315 - Robles, Thiago (por T1T0Dev)
# PR #70: TP2 - 61719 - Amoedo, Pablo Isaias (por Kryfter)
# PR #71: TP2 - 61271 - Donelli, Gerardo Exequiel (por GerardoExe)
# PR #72: TP2 - 61221 - Duclós, Marcelo Ezequiel (por EzeDuclos)
# PR #73: TP2 - 61338 - Morales, Juan Daniel (por JuanMo17)
# PR #74: TP2 - 61203 - Acevedo Costello, Juan Ignacio (por Ignacioacevedoo)
# PR #75: TP2 - 61203 - Acevedo Costello, Juan Ignacio (por Ignacioacevedoo)
# PR #76: TP2 - 61073 - Gonzalez Chavez, Rodrigo (por rodrigogc21)
# PR #77: TP2 - 61033 - Quiroga, Jose Maria (por jose-qui)
# PR #78: TP2 - 61131 - Agostino Colombres, Juan Manuel (por JuanmaAgostino)
# PR #79: TP2 - 61312 - Paz Berrondo, Lucas David (por Lucasdxvid)
# PR #80: TP2 - 61037 - Paz, Rodrigo Federico (por Rodrigopz52)
# PR #81: TP2 - 61240 - Timo, Hector Gabriel (por GabrielTimo006)
# PR #82: TP2 - 61626 - Diaz Londero, Sergio Gonzalo (por Gonzalo-diazz)
# PR #83: TP2 - 61167 - Giacobbe, Franco (por frandg47)
# PR #84: TP2 - 62093 - Frias Silva, Juan Segundo (por juansefriass)
# PR #85: TP2 - 61473 - Lagoria Garcia, Tomás Gustavo (por tomaslago27)
# PR #86: TP2 - 61624 - Godoy, Alan (por AlanG46)
# PR #87: TP2 - 62055 - Aumada, Aiquen Osvaldo (por aiquen7)
# PR #88: TP2 - 61445 - Martínez Campero, Santiago (por SantiCampero)
# PR #89: TP2 - 62053 - Herrera Palomino, Ivan Agustín (por ivanagustinherrera)
# PR #90: TP2 - 61198 - Ferreyra Appas, Santiago Nicolas (por Ercutt)
# PR #91: TP2 - 61627 - Juarez Fernandez, Lourdes Abril (por LourdesFernandez1)
# PR #92: TP2 - 61136 - Sosa, Oscar Ignacio (por Oscar40997)
# PR #93: TP2 - 62555 - Verón, Matias Gabriel (por MatiasVeron12503)
# PR #94: TP2 - 61911 - Llanos, Luciano (por LucianoLlanos)
# PR #95: TP2 - 61046 - Ponce, Luz Micaela (por Mica8p)
# PR #96: TP2 - 61335 - Leon, Lucas Ismael (por LuquitasLeon)
# PR #97: TP2 - 61115 - Ledesma, Santiago Esteban (por santled)
# PR #98: TP1 - 61150 - Molina Navarro, Juan Martin (por JuanMolinaNavarro)
# PR #99: TP2 - 61236 - Drachenberg, Franco Eduardo (por FDrach)
# PR #100: TP2 - 61478 - Soto, Antonella (por anto210)
# PR #101: TP2 - 61084 - Ramirez, Leonardo (por Leoramirez777)
# PR #102: TP2 - 61818 - Lopez, Tisera Gaston (por gastonlopezt)
# PR #103: TP2 - 61725 - Villagra, Jorge Sebastián (por JorgeVillagraa)
# PR #104: TP2 - 61468 - MaxiSama12 (por MaxiSama12)
# PR #105: TP2 - 61028 - Ponce, Rodrigo Exequiel (por rodrikapo12)
# PR #106: TP2 - 61468 - Samaniego, Esteban Maximiliano (por MaxiSama12)
# PR #107: TP2 - 62263 - Orellana, José Augusto (por Jaodem)
# PR #108: TP2 - 61035 - Ledesma, Paulo Marcelo (por pauloled)
# PR #109: TP2 - 61794 - Lobo Campero, Hernán Ignacio (por lobohhernan)
# PR #110: TP2 - 61676 - Massey, Maximiliano (por EPILONgaga)
# PR #111: TP2 - 61113 - Oríz Caballero, Juan José (por JuanchoCab)
# PR #112: TP2 - 61793 - Trujillo, Facundo Nahuel (por FacundoTrujillo)
# PR #113: TP2 - 61319 - Carabajal, José Gabriel (por 7GabrielC)
# PR #114: TP2 - 61565 - Carrizo, Mauro (por DarkoDarkShadow)
# PR #115: TP2 - 61150 - Molina Navarro, Juan Martin (por JuanMolinaNavarro)
# PR #116: TP2 - 54911 - Jatib, Rodrigo Gabriel (por RodrigoJatib)
# PR #117: TP2 - 62175 - Quiroga, Marcela Noemi Quiroga (por Marce-Quiroga)
# PR #118: TP2 - 61032 - Moya, Mariano (por mariano-moya)
# PR #119: TP2 - 61450 - Jimenez Paz, Patricio Agustín (por patricio-jp)
# PR #120: TP2 - 61141 - Di Clemente, Maria Antonela (por antodiclemente)
# PR #121: TP2 - 61139 - Gallo, María Matilde (por matildegallom)
# PR #122: TP2 - 61248 - Palma Collado, Nahuel (por Nahu333)
# PR #123: TP2 - 61197 - Romano, Alfredo Nicolás (por NicoRomano904)
# PR #124: TP2 - 61667 - Acosta, Maira (por maira-acostaa)
# PR #125: TP2 - 61096 - Suárez Vece, Leandro Andrés (por leandroVece)
# [{'legajo': '54911', 'nombre': 'Jatib, Rodrigo Gabriel', 'telefono': '(381) 655-3096', 'estado': 'a', 'comision': 'C1', 'github': 'RodrigoJatib'}, {'legajo': '61033', 'nombre': 'Quiroga, José María', 'telefono': '(11) 2399-7675', 'estado': 'a', 'comision': 'C1', 'github': 'jose-qui'}, {'legajo': '61035', 'nombre': 'Ledesma, Paulo Marcelo', 'telefono': '(381) 664-8356', 'estado': 'a', 'comision': 'C1', 'github': 'pauloled'}, {'legajo': '61046', 'nombre': 'Ponce, Luz Micaela', 'telefono': '(381) 664-7165', 'estado': 'a', 'comision': 'C1', 'github': 'Mica8p'}, {'legajo': '61073', 'nombre': 'González Chavez, Rodrigo', 'telefono': '(381) 624-3000', 'estado': 'a', 'comision': 'C1', 'github': 'rodrigogc21'}, {'legajo': '61084', 'nombre': 'Ramírez, Leonardo', 'telefono': '(381) 348-9132', 'estado': 'a', 'comision': 'C1', 'github': 'Leoramirez777'}, {'legajo': '61115', 'nombre': 'Ledesma, Santiago Esteban', 'telefono': '(381) 346-3696', 'estado': 'a', 'comision': 'C1', 'github': 'santled'}, {'legajo': '61120', 'nombre': 'Guerrero, Ana Sofía', 'telefono': '(381) 418-1564', 'estado': 'c', 'comision': 'C1', 'github': 'AnaSofi03'}, {'legajo': '61131', 'nombre': 'Agostino Colombres, Juan Manuel', 'telefono': '(381) 684-8399', 'estado': 'a', 'comision': 'C1', 'github': 'JuanmaAgostino'}, {'legajo': '61167', 'nombre': 'Giacobbe, Franco', 'telefono': '(381) 588-0371', 'estado': 'a', 'comision': 'C1', 'github': 'frandg47'}, {'legajo': '61198', 'nombre': 'Ferreyra Appas, Santiago Nicolás', 'telefono': '(381) 648-4455', 'estado': 'a', 'comision': 'C1', 'github': 'Ercutt'}, {'legajo': '61236', 'nombre': 'Drachenberg, Franco Eduardo', 'telefono': '(381) 670-8708', 'estado': 'a', 'comision': 'C1', 'github': 'FDrach'}, {'legajo': '61240', 'nombre': 'Timo, Héctor Gabriel', 'telefono': '(381) 343-0992', 'estado': 'a', 'comision': 'C1', 'github': 'GabrielTimo006'}, {'legajo': '61315', 'nombre': 'Robles, Thiago', 'telefono': '(381) 344-7120', 'estado': 'a', 'comision': 'C1', 'github': 'T1T0Dev'}, {'legajo': '61335', 'nombre': 'León, Lucas Ismael', 'telefono': '(381) 609-7898', 'estado': 'a', 'comision': 'C1', 'github': 'LuquitasLeon'}, {'legajo': '61337', 'nombre': 'Díaz, Christian Gabriel', 'telefono': '(381) 571-4797', 'estado': 'a', 'comision': 'C1'}, {'legajo': '61338', 'nombre': 'Morales, Juan Daniel', 'telefono': '(381) 665-5296', 'estado': 'a', 'comision': 'C1', 'github': 'JuanMo17'}, {'legajo': '61463', 'nombre': 'González, Vladimir', 'telefono': '(381) 419-4154', 'estado': 'x', 'comision': 'C1'}, {'legajo': '61468', 'nombre': 'Samaniego, Esteban Maximiliano', 'telefono': '(381) 679-6586', 'estado': 'a', 'comision': 'C1', 'github': 'MaxiSama12'}, {'legajo': '61472', 'nombre': 'Díaz, Julieta Camila', 'telefono': '(381) 652-9981', 'estado': 'x', 'comision': 'C1', 'github': 'juliidiiaz04'}, {'legajo': '61551', 'nombre': 'Díaz Valdez, Ignacio', 'telefono': '(381) 695-8566', 'estado': 'a', 'comision': 'C1', 'github': 'IgnacioDiazV'}, {'legajo': '61565', 'nombre': 'Carrizo, Mauro', 'telefono': '(381) 610-8745', 'estado': 'a', 'comision': 'C1', 'github': 'DarkoDarkShadow'}, {'legajo': '61725', 'nombre': 'Villagra, Jorge Sebastián', 'telefono': '(381) 594-1635', 'estado': 'l', 'comision': 'C1', 'github': 'JorgeVillagraa'}, {'legajo': '61805', 'nombre': 'Jerez, Tomás', 'telefono': '(381) 338-0186', 'estado': 'a', 'comision': 'C1', 'github': 'ElTommmy'}, {'legajo': '61813', 'nombre': 'Figueroa, Manuel', 'telefono': '(381) 544-2423', 'estado': 'c', 'comision': 'C1'}, {'legajo': '61911', 'nombre': 'Llanos, Luciano', 'telefono': '(381) 325-9224', 'estado': 'a', 'comision': 'C1', 'github': 'LucianoLlanos'}, {'legajo': '61993', 'nombre': 'Medina, Juan Ignacio', 'telefono': '(381) 517-1937', 'estado': 'a', 'comision': 'C1'}, {'legajo': '62171', 'nombre': 'Ballespin, Cristián', 'telefono': '(381) 604-5734', 'estado': 'c', 'comision': 'C1'}, {'legajo': '62175', 'nombre': 'Quiroga, Marcela Noemí', 'telefono': '(381) 593-8430', 'estado': 'a', 'comision': 'C1', 'gith ...
